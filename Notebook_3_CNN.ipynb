# %% [markdown]
# # Notebook 2: CNN
#
# ## Overview:
#
# 1. Begin by importing and getting the embeddings and word to index mappings we created in [Notebook 1: Embed Words](Notebook_1_Embed_Words.ipynb)

# %%
import cPickle as pickle
from tensorflow.models.rnn.rnn_cell import BasicLSTMCell, LSTMCell 
import itertools
from collections import Counter
import csv
import re
import numpy as np

# %%
embeddings = None
mappings = None
rows = None

with open("word_embeddings.pkl", "rb") as f:
    embeddings = pickle.load(f)
with open("word_mappings.pkl", "rb") as f:
    mappings = pickle.load(f)
    

urlFinder = re.compile('\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*')

exclude_punc = set([
        "!",
        "?",
        ".",
        ",",
        ":",
        ";",
        "'",
        "\"",
        "“",
        "’",
        "-"
])


sentences = []
labels = []
x = []
y = []

with open('data.csv', 'rb') as f:
    reader = csv.reader(f, delimiter=',')   
    
    for row in reader:
        words = []
        
        for word in row[1] \
            .strip() \
            .replace("&amp;", "") \
            .replace("&gt;","") \
            .replace("&lt;", "") \
            .lower().split():
            
            if urlFinder.match(word):
                words.append("<URL/>")
            else:
                word = ''.join(ch for ch in word if ch not in exclude_punc)
                words.append(word)
        sentences.append(words)
        labels.append(([0, 1] if row[0] == "example" else [1, 0]))


sequence_length = max(len(i) for i in sentences)
padded_sentences = []
for i in range(len(sentences)):
    sentence = sentences[i]
    num_padding = sequence_length - len(sentence)
    new_sentence = sentence + ["<PAD/>"] * num_padding
    padded_sentences.append(new_sentence)
    
 
word_counts = Counter(itertools.chain(*padded_sentences))

# Mapping from index to word
vocabulary_inv = [x[0] for x in word_counts.most_common()]
# Mapping from word to index
vocabulary = {x: i for i, x in enumerate(vocabulary_inv)}

x = np.array([[vocabulary[word] for word in sentence] for sentence in padded_sentences])
y = np.array(labels)

# %%
import tensorflow as tf
import numpy as np


class TextCNN(object):
    """
    A CNN for text classification.
    Uses an embedding layer, followed by a convolutional, max-pooling and softmax layer.
    """
    def __init__(
      self, sequence_length, num_classes, vocab_size,
      embedding_size, filter_sizes, num_filters, l2_reg_lambda=0.0):

        # Placeholders for input, output and dropout
        self.input_x = tf.placeholder(tf.int32, [None, sequence_length], name="input_x")
        self.input_y = tf.placeholder(tf.float32, [None, num_classes], name="input_y")
        self.dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")

        # Keeping track of l2 regularization loss (optional)
        l2_loss = tf.constant(0.0)

        # Embedding layer
        with tf.device('/cpu:0'), tf.name_scope("embedding"):
            W = tf.Variable(
                tf.random_uniform([vocab_size, embedding_size], -1.0, 1.0),
                name="W")
            self.embedded_chars = tf.nn.embedding_lookup(W, self.input_x)
            self.embedded_chars_expanded = tf.expand_dims(self.embedded_chars, -1)

        # Create a convolution + maxpool layer for each filter size
        pooled_outputs = []
        for i, filter_size in enumerate(filter_sizes):
            with tf.name_scope("conv-maxpool-%s" % filter_size):
                # Convolution Layer
                filter_shape = [filter_size, embedding_size, 1, num_filters]
                W = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W")
                b = tf.Variable(tf.constant(0.1, shape=[num_filters]), name="b")
                conv = tf.nn.conv2d(
                    self.embedded_chars_expanded,
                    W,
                    strides=[1, 1, 1, 1],
                    padding="VALID",
                    name="conv")
                # Apply nonlinearity
                h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                # Maxpooling over the outputs
                pooled = tf.nn.max_pool(
                    h,
                    ksize=[1, sequence_length - filter_size + 1, 1, 1],
                    strides=[1, 1, 1, 1],
                    padding='VALID',
                    name="pool")
                pooled_outputs.append(pooled)

        # Combine all the pooled features
        num_filters_total = num_filters * len(filter_sizes)
        self.h_pool = tf.concat(3, pooled_outputs)
        self.h_pool_flat = tf.reshape(self.h_pool, [-1, num_filters_total])

        # Add dropout
        with tf.name_scope("dropout"):
            self.h_drop = tf.nn.dropout(self.h_pool_flat, self.dropout_keep_prob)

        # Final (unnormalized) scores and predictions
        with tf.name_scope("output"):
            W = tf.Variable(tf.truncated_normal([num_filters_total, num_classes], stddev=0.1), name="W")
            b = tf.Variable(tf.constant(0.1, shape=[num_classes]), name="b")
            l2_loss += tf.nn.l2_loss(W)
            l2_loss += tf.nn.l2_loss(b)
            self.scores = tf.nn.xw_plus_b(self.h_drop, W, b, name="scores")
            self.predictions = tf.argmax(self.scores, 1, name="predictions")

        # CalculateMean cross-entropy loss
        with tf.name_scope("loss"):
            losses = tf.nn.softmax_cross_entropy_with_logits(self.scores, self.input_y)
            self.loss = tf.reduce_mean(losses) + l2_reg_lambda * l2_loss

        # Accuracy
        with tf.name_scope("accuracy"):
            correct_predictions = tf.equal(self.predictions, tf.argmax(self.input_y, 1))
            self.accuracy = tf.reduce_mean(tf.cast(correct_predictions, "float"), name="accuracy")

# %%
def batch_iter(data, batch_size, num_epochs):
    """
    Generates a batch iterator for a dataset.
    """
    data = np.array(data)
    data_size = len(data)
    num_batches_per_epoch = int(len(data)/batch_size) + 1
    for epoch in range(num_epochs):
        # Shuffle the data at each epoch
        shuffle_indices = np.random.permutation(np.arange(data_size))
        shuffled_data = data[shuffle_indices]
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, data_size)
            yield shuffled_data[start_index:end_index]

# %%
import tensorflow as tf
import numpy as np
import os
import time
import datetime

# Parameters
# ==================================================

# Model Hyperparameters
embedding_dim = 128  #Dimensionality of character embedding (default: 128)
filter_sizes =  "3,4,5" #"Comma-separated filter sizes (default: '3,4,5')")
num_filters = 128  #"Number of filters per filter size (default: 128)")
dropout_keep_prob = 0.5 #"Dropout keep probability (default: 0.5)")
l2_reg_lambda = 0.0 #"L2 regularizaion lambda (default: 0.0)")

# Training parameters
batch_size = 10 # "Batch Size (default: 64)")
num_epochs = 20 #"Number of training epochs (default: 200)")
evaluate_every = 1000  #"Evaluate model on dev set after this many steps (default: 100)")
checkpoint_every = 10000 # "Save model after this many steps (default: 100)")
# Misc Parameters
allow_soft_placement = True # "Allow device soft device placement")
log_device_placement = False  #"Log placement of ops on devices")
display_train_steps = False # toggles output of training step results



# Data Preparatopn
# ==================================================

# Load data
print("Loading data...")
# Randomly shuffle data
np.random.seed(10)
shuffle_indices = np.random.permutation(np.arange(len(y)))
x_shuffled = x[shuffle_indices]
y_shuffled = y[shuffle_indices]
# Split train/test set
# TODO: This is very crude, should use cross-validation
x_train, x_dev = x_shuffled[:len(x_shuffled)-1], x_shuffled[-len(x_shuffled)-1:]
y_train, y_dev = y_shuffled[:len(y_shuffled)-1], y_shuffled[-len(y_shuffled)-1:]
print("Vocabulary Size: {:d}".format(len(vocabulary)))
print("Train/Dev split: {:d}/{:d}".format(len(y_train), len(y_dev)))
print("Train Pos/Dev Pos Split {:d}/{:d}"
      .format(
        len(
            [y for y in y_train if y[0] == 0 and y[1] == 1]
        ), len(
            [y for y in y_dev if y[0] == 0 and y[1] == 1]
        )))
print("Train Neg/Dev Neg Split {:d}/{:d}"
      .format(
        len(
            [y for y in y_train if y[0] == 1 and y[1] == 0]
        ), len(
            [y for y in y_dev if y[0] == 1 and y[1] == 0]
        )))


# Training
# ==================================================

with tf.Graph().as_default():
    session_conf = tf.ConfigProto(
      allow_soft_placement=allow_soft_placement,
      log_device_placement=log_device_placement)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        cnn = TextCNN(
            sequence_length=x_train.shape[1],
            num_classes=2,
            vocab_size=len(vocabulary),
            embedding_size=embedding_dim,
            filter_sizes=map(int, filter_sizes.split(",")),
            num_filters=num_filters,
            l2_reg_lambda=l2_reg_lambda)

        # Define Training procedure
        global_step = tf.Variable(0, name="global_step", trainable=False)
        optimizer = tf.train.AdamOptimizer(1e-4)
        grads_and_vars = optimizer.compute_gradients(cnn.loss)
        train_op = optimizer.apply_gradients(grads_and_vars, global_step=global_step)

        # Keep track of gradient values and sparsity (optional)
        grad_summaries = []
        for g, v in grads_and_vars:
            if g is not None:
                grad_hist_summary = tf.histogram_summary("{}/grad/hist".format(v.name), g)
                sparsity_summary = tf.scalar_summary("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                grad_summaries.append(grad_hist_summary)
                grad_summaries.append(sparsity_summary)
        grad_summaries_merged = tf.merge_summary(grad_summaries)

        # Output directory for models and summaries
        timestamp = str(int(time.time()))
        out_dir = os.path.abspath(os.path.join(os.path.curdir, "runs", timestamp))
        print("Writing to {}\n".format(out_dir))

        # Summaries for loss and accuracy
        loss_summary = tf.scalar_summary("loss", cnn.loss)
        acc_summary = tf.scalar_summary("accuracy", cnn.accuracy)

        # Train Summaries
        train_summary_op = tf.merge_summary([loss_summary, acc_summary, grad_summaries_merged])
        train_summary_dir = os.path.join(out_dir, "summaries", "train")
        train_summary_writer = tf.train.SummaryWriter(train_summary_dir, sess.graph_def)

        # Dev summaries
        dev_summary_op = tf.merge_summary([loss_summary, acc_summary])
        dev_summary_dir = os.path.join(out_dir, "summaries", "dev")
        dev_summary_writer = tf.train.SummaryWriter(dev_summary_dir, sess.graph_def)

        # Checkpoint directory. Tensorflow assumes this directory already exists so we need to create it
        checkpoint_dir = os.path.abspath(os.path.join(out_dir, "checkpoints"))
        checkpoint_prefix = os.path.join(checkpoint_dir, "model")
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        saver = tf.train.Saver(tf.all_variables())

        # Initialize all variables
        sess.run(tf.initialize_all_variables())

        def train_step(x_batch, y_batch):
            """
            A single training step
            """
            feed_dict = {
              cnn.input_x: x_batch,
              cnn.input_y: y_batch,
              cnn.dropout_keep_prob: dropout_keep_prob
            }
            _, step, summaries, loss, accuracy = sess.run(
                [train_op, global_step, train_summary_op, cnn.loss, cnn.accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            if(display_train_steps):
                print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
            train_summary_writer.add_summary(summaries, step)

        def dev_step(x_batch, y_batch, writer=None):
            """
            Evaluates model on a dev set
            """
            feed_dict = {
              cnn.input_x: x_batch,
              cnn.input_y: y_batch,
              cnn.dropout_keep_prob: 1.0
            }
            step, summaries, loss, accuracy = sess.run(
                [global_step, dev_summary_op, cnn.loss, cnn.accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
            if writer:
                writer.add_summary(summaries, step)

        # Generate batches
        batches = batch_iter(
            zip(x_train, y_train), batch_size, num_epochs)
        # Training loop. For each batch...
        for batch in batches:
            x_batch, y_batch = zip(*batch)
            train_step(x_batch, y_batch)
            current_step = tf.train.global_step(sess, global_step)
            if current_step % evaluate_every == 0:
                print("\nEvaluation:")
                dev_step(x_dev, y_dev, writer=dev_summary_writer)
                print("")
            if current_step % checkpoint_every == 0:
                path = saver.save(sess, checkpoint_prefix, global_step=current_step)
                print("Saved model checkpoint to {}\n".format(path))
        
        print("\nFinal Evaluations:")
        dev_step(x_dev, y_dev, writer=dev_summary_writer)
  
        
        print("")
# Out:
# Loading data...
# Vocabulary Size: 5640
# Train/Dev split: 2983/2984
# Train Pos/Dev Pos Split 211/211
# Train Neg/Dev Neg Split 2772/2773
# Writing to /notebooks/AdHClassification/Expiriment #1.2 - Candidate Tweets More Data/runs/1456852514
#
#
# Evaluation:
# 2016-03-01T17:16:57.099851: step 1000, loss 0.395091, acc 0.92929
#
#
# Evaluation:
# 2016-03-01T17:18:39.344240: step 2000, loss 0.164728, acc 0.939008
#
#
# Evaluation:
# 2016-03-01T17:20:18.458630: step 3000, loss 0.0887808, acc 0.959786
#
#
# Evaluation:
# 2016-03-01T17:21:57.349233: step 4000, loss 0.0356467, acc 0.981568
#
#
# Evaluation:
# 2016-03-01T17:23:35.995333: step 5000, loss 0.0177975, acc 0.994638
#
#
# Final Evaluations:
# 2016-03-01T17:25:12.663667: step 5980, loss 0.0133602, acc 0.996984

# %%
        pos_x_dev = []
        pos_y_dev = []

        neg_x_dev = []
        neg_y_dev = []

        for y, x in zip(y_dev, x_dev):
            if(y[0] == 0 and y[1] == 1):
                pos_x_dev.append(x)
                pos_y_dev.append(y)
            else:
                neg_x_dev.append(x)
                neg_y_dev.append(y)
        even_x_dev = np.array(pos_x_dev + neg_x_dev[:len(pos_x_dev)])
        even_y_dev = np.array(pos_y_dev + neg_y_dev[:len(pos_y_dev)])
        print(len(even_y_dev), len(even_x_dev))

        print("Balanced Evaluation:")
        dev_step(even_x_dev, even_y_dev, writer=dev_summary_writer)
# Out:
# (422, 422)
# Balanced Evaluation:
# 2016-03-01T17:25:12.908898: step 5980, loss 0.091889, acc 0.978673

# %%
    for y, x in zip(even_y_dev, even_x_dev):
        sent = []
        for word in x:
            sent.append(vocabulary_inv[word])
        print(' '.join(sent))
        print("example" if y[0] == 0 and y[1] == 1 else "nonexample")
        dev_step([x], [y], writer=dev_summary_writer)
        print("")
        print("")
# Out:
# dopey mort zuckerman owner of the worthless @nydailynews has a major inferiority complex paper will close soon <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.923318: step 5980, loss 0.019731, acc 1
#
#
# @bensasse looks more like a gym rat than a us senator how the hell did he ever get elected @greta <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.928846: step 5980, loss 0.00712497, acc 1
#
#
# jebs tested transparent to get @hillaryclintons info you need a subpoena #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.936159: step 5980, loss 0.24371, acc 1
#
#
# @piersmorgan jeb bush was as ineffectual as ever as always @david_gergen calls it right trump held them off #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.942043: step 5980, loss 0.0382139, acc 1
#
#
# three times @hillaryclinton refused to answer the question #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.947104: step 5980, loss 0.559048, acc 1
#
#
# pathetic attempt by @foxnews to try and build up ratings for the #gopdebate without me theyd have no ratings <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.950825: step 5980, loss 0.424522, acc 1
#
#
# its not tough to take an elderly womans home @realdonaldtrump #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.954683: step 5980, loss 0.0554262, acc 1
#
#
# ted cruz is lying again polls are showing that i do beat hillary clinton head to head check out <URL/> poll snd q poll <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.958407: step 5980, loss 0.0556762, acc 1
#
#
# response to the lies of senator cruz <URL/> #trump2016 #votetrumpsc <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.963109: step 5980, loss 0.525492, acc 1
#
#
# flashback hillary clinton unaccompanied minors should be sent back <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.967697: step 5980, loss 0.0694843, acc 1
#
#
# @marcorubio time to come up with a new script #notready <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.971602: step 5980, loss 0.360584, acc 1
#
#
# mitt romney who was one of the dumbest and worst candidates in the history of republican politics is now pushing me on tax returns dope <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.976514: step 5980, loss 0.18899, acc 1
#
#
# why would texans vote for liar ted cruz when he was born in canada lived there for 4 yearsand remained a canadian citizen until recently <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.980254: step 5980, loss 0.00337686, acc 1
#
#
# take a look at jeb’s record as a conservative reformer vs @marcorubio’s record as a donothing senator #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.984288: step 5980, loss 0.421696, acc 1
#
#
# great night at the #gopdebate i took on @realdonaldtrump to show he is unfit to serve as commanderinchief watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.987706: step 5980, loss 0.117577, acc 1
#
#
# clinton electability faces scrutiny <URL/> via mark gersh <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.991798: step 5980, loss 0.286756, acc 1
#
#
# track two from the album #scripted in essence <URL/> cc @marcorubio <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:12.997577: step 5980, loss 0.0202112, acc 1
#
#
# @henryoray @cnnpolitics @tedcruz @realdonaldtrump is fighting corruption big donors took over cruz no to donors <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.001860: step 5980, loss 0.00542099, acc 1
#
#
# @marcorubio cut and ran on his policy stances when his position became politically unpopular <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.006516: step 5980, loss 0.0156129, acc 1
#
#
# the iranians know a mark when they see one want more concessions before obama leaves office <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.011044: step 5980, loss 0.106801, acc 1
#
#
# dont let #duckingdonald skip the debate get your #maketrumpdebateagain hat today  <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.015363: step 5980, loss 0.291574, acc 1
#
#
# remember that marco rubio is very weak on illegal immigration south carolina needs strength as illegals and syrians pour in dont allow it <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.019785: step 5980, loss 0.16918, acc 1
#
#
# @truthinvest @cnn @tedcruz @realdonaldtrump ted cruz is the definition of sleaze just ask @realbencarson <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.023810: step 5980, loss 0.00512655, acc 1
#
#
# washington is broken and both parties are to blame <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.029901: step 5980, loss 0.478512, acc 1
#
#
# everybody is laughing at jeb bushspent $100 million and is at bottom of pack a pathetic figure <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.034245: step 5980, loss 0.0316707, acc 1
#
#
# @realdonaldtrump is trafficking 9/11 conspiracy theories i’m offering detailed plans to defeat isis we need a serious commanderinchief <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.038585: step 5980, loss 0.177222, acc 1
#
#
# i hear that @sentedcruz’s $$ man robert mercer a good man is very angry because cruz lied to him about liquidating his (ted’s) holdings <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.042688: step 5980, loss 0.0539478, acc 1
#
#
# just watched the very incompetent mitt romney campaign strategist stuart stevens now i know why mitt lost so badly stevens is a clown <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.046833: step 5980, loss 0.158682, acc 1
#
#
# watching biased charles @krauthammer a @foxnews flunky who didnt know that i won every debate in particular the last one check polls <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.051201: step 5980, loss 0.290489, acc 1
#
#
# @laurencristmann @realdonaldtrump why do they have so many debates this year also why is cruz still allowed to run hes not eligible <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.055696: step 5980, loss 0.0484486, acc 1
#
#
# while @realdonaldtrump was building a reality tv show my brother was building a security apparatus to keep us safe #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.060682: step 5980, loss 0.0245677, acc 1
#
#
# jeb is a hypocrite used massive private eminent domain  just another clueless politician <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.065337: step 5980, loss 0.0318964, acc 1
#
#
# hey @glennbeck see how i beat your boy ted in your own blaze poll your endorsement means nothing #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.069496: step 5980, loss 0.132684, acc 1
#
#
# @lindseygraham who had zero in his presidential run before dropping out in disgrace saying the most horrible things about me on @foxnews <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.073446: step 5980, loss 0.0603572, acc 1
#
#
# taking an elderly womans home to build a parking lot for a failed casino isnt the proper use of eminent domain @realdonaldtrump #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.076864: step 5980, loss 0.323204, acc 1
#
#
# make sure you get on the trump line and are not mislead by the cruz people they are bad be careful <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.081825: step 5980, loss 0.114065, acc 1
#
#
# rt if you agree donald trump should release his tax returns <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.085802: step 5980, loss 0.0432858, acc 1
#
#
# @realollietaylor @paintonmy ia caucus hasnt picked nominee in 16 years cruz dirty tricks stole it trump way ahead in primary states <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.089527: step 5980, loss 0.0793302, acc 1
#
#
# track three of @marcorubios album #scripted votes dont mean a thing <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.094838: step 5980, loss 0.13917, acc 1
#
#
# bonus track a ballad of love loss and amnesty from @marcorubios album #scripted <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.098661: step 5980, loss 0.22783, acc 1
#
#
# we are getting reports from many voters that the cruz people are back to doing very sleazy and dishonest pushpolls on me we are watching <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.102609: step 5980, loss 0.148798, acc 1
#
#
# remembering back when @realdonaldtrump wasnt attacking conservatives <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.106431: step 5980, loss 0.0158516, acc 1
#
#
# @tdltdltdltdl marco cruz and ted rubio (easy to get the two politicians confused) looked like desperate panicked dc insiders tonight <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.110557: step 5980, loss 0.0182413, acc 1
#
#
# @berniesanders i wont cut social security as always ill defend it ill expand it enough false innuendos <URL/> h <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.114602: step 5980, loss 0.439257, acc 1
#
#
# word is that little morty zuckerman’s @nydailynews loses more than $50 million per yearcan that be possible <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.119173: step 5980, loss 0.00815739, acc 1
#
#
# president obama’s foreign policy has consistently alienated and abandoned our friends while showing our enemies appeasement #goptownhall <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.124406: step 5980, loss 0.0843079, acc 1
#
#
# the new email release is a disaster for hillary clinton at a minimum how can someone with such bad judgement be our next president <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.128407: step 5980, loss 0.327068, acc 1
#
#
# both donald trump hillary want to be neutral between israel and the palestinians if im elected well stand unapologetically with israel <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.133144: step 5980, loss 0.400101, acc 1
#
#
# how can ted cruz be an evangelical christian when he lies so much and is so dishonest <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.137473: step 5980, loss 0.00555069, acc 1
#
#
# last time lightweight @jebbush tried to knock off @marcorubio he made a total fool of himself if he doesnt do better this time he is out <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.140993: step 5980, loss 0.00481102, acc 1
#
#
# enough with playground pranks and disparaging americans @realdonaldtrump we need a real leader <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.144523: step 5980, loss 0.126992, acc 1
#
#
# were never going to get anything done in washington if our leaders cut and run @marcorubio #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.149291: step 5980, loss 0.240662, acc 1
#
#
# when mitt romney asked me for my endorsement last time around he was so awkward and goofy that we all should have known he could not win <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.155736: step 5980, loss 0.01134, acc 1
#
#
# going to tonights #gopdebate look for this #duckingdonald @snapchat filter  <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.160654: step 5980, loss 0.732807, acc 0
#
#
# @conservativevin @ahernandez85a romney should have been a tough guy with obama he cowered and lost badly hes not relevant <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.164364: step 5980, loss 0.00435013, acc 1
#
#
# like the worthless @nydailynews looks like @politico will be going out of business bad reporting no money no cred <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.167588: step 5980, loss 0.389178, acc 1
#
#
# jeb bush spent more than $40000000 in new hampshire to come in 4 or 5 i spent $3000000 to come in 1st big difference in capability <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.170535: step 5980, loss 1.61257, acc 0
#
#
# why would the people of florida vote for marco rubio when he defrauded them by agreeing to represent them as their senator and then quit <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.175208: step 5980, loss 0.0820845, acc 1
#
#
# lightweight marco rubio was working hard last night the problem is he is a choker and once a choker always a chocker mr meltdown <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.178677: step 5980, loss 0.00534984, acc 1
#
#
# as the media discovers more facts surrounding ted cruzs campaign resorting to dirty tricks even they are appalled <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.181890: step 5980, loss 0.0775031, acc 1
#
#
# @realdonaldtrump showing class grace calls me a soft weak little baby hope he doesnt try to eat me <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.186090: step 5980, loss 0.00631978, acc 1
#
#
# the failing @nydailynews destroyed by little morty zuckerman is preparing to close and save face by going online its dead <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.189388: step 5980, loss 0.0423587, acc 1
#
#
# after hearing the news that they would not be able to extort $1m from me they went hostile w/ a series of incorrect illinformed ads <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.193711: step 5980, loss 0.203437, acc 1
#
#
# @realdonaldtrump do you know who else is scared of tough qs from fox @megynkelly barack obama enough whining <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.203489: step 5980, loss 0.0118163, acc 1
#
#
# how can @jebbush beat hillary clinton if he cant beat anyone else on the #gopdebate stage with $150m i am the only one who can <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.217493: step 5980, loss 0.107666, acc 1
#
#
# lightweight @jebbush said tonight he didnt know his family used private eminent domain in texas lie #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.221378: step 5980, loss 0.00209981, acc 1
#
#
# @hillaryclinton put americas secrets at risk for her convenience <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.225666: step 5980, loss 0.00448127, acc 1
#
#
# all polls have me winning debate big drudge time etc dopey charles krauthammer still nasty he has zero cred totally dishonest <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.229984: step 5980, loss 0.00570064, acc 1
#
#
# yet more details about how @hillaryclinton put her political security ahead of national security <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.233910: step 5980, loss 0.132015, acc 1
#
#
# really dumb @cherijacobus begged my people for a job turned her down twice and she went hostile major loser zero credibility <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.239045: step 5980, loss 0.0559454, acc 1
#
#
# the reason that ted cruz lost the evangelicals in sc is because he is a world class liar and evangelicals do not like liars <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.243075: step 5980, loss 0.0178831, acc 1
#
#
# it’s official the fbi confirms it is investigating hillary clinton’s private server <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.247677: step 5980, loss 0.335994, acc 1
#
#
# its been 17 days 16 hours and 32 minutes since @hillaryclinton said she would look into releasing her paid speeches to wall street <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.251945: step 5980, loss 0.00733196, acc 1
#
#
# @resistyr mrtrumpboth cruz and rubio are ineligible to be potus its a slam dunk case check it <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.257031: step 5980, loss 0.386234, acc 1
#
#
# when little morty zuckerman closes his failing @nydailynews will i at least be given some credit will happen soon <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.261336: step 5980, loss 0.118149, acc 1
#
#
# @hillaryclinton put americas secrets at risk for her convenience #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.265141: step 5980, loss 0.0023823, acc 1
#
#
# falsely accusing someone of lying is itself a lie and its something @realdonaldtrump does daily #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.268754: step 5980, loss 0.0411481, acc 1
#
#
# the failing @wsj wall street journal should fire both its pollster and its editorial board seldom has a paper been so wrongtotally biased <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.272244: step 5980, loss 0.0450828, acc 1
#
#
# ted cruz does not have the right temperment to be president look at the way he totally panicked in firing his director of comm bad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.276053: step 5980, loss 0.0561442, acc 1
#
#
# nasty ted cruz is at it again same dirty tricks he used w/ @realbencarson saying i may not be on ballot i hold liberal positions lies <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.279896: step 5980, loss 0.0228871, acc 1
#
#
# @donell27743094 @realdonaldtrump trump won the debate disgusting rubio said peed  is he still in junior high school <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.283606: step 5980, loss 0.026182, acc 1
#
#
# the screaming you hear now from across the potomac is the #washingtoncartel in full terror that the conservative grassroots are rising up <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.286991: step 5980, loss 0.889513, acc 0
#
#
# @enlighten2881 @ukcatwoman52 @ericnlin @ac360 how come rubiocruz are going to turn america around but did nothing in the senate for usa <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.291494: step 5980, loss 0.21486, acc 1
#
#
# if @realdonaldtrump can’t handle the @foxnews debate what else will he not be able to handle <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.295507: step 5980, loss 0.026421, acc 1
#
#
# @hosiern @foxnewspolitics a vote for @tedcruz or @marcorubio is a vote for corruption special interests and lobbyists trump for potus <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.298875: step 5980, loss 0.162925, acc 1
#
#
# track one of the album #scripted is i got 3 questions but only 1 answer cc @marcorubio <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.302597: step 5980, loss 0.0106637, acc 1
#
#
# jeb bush has zero communication skills so he spent a fortune of special interest money on a super bowl ad he is a weak candidate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.306502: step 5980, loss 0.0119181, acc 1
#
#
# wow was ted cruz disloyal to his very capable director of communication he used him as a scape goatfired like a dog ted panicked <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.311624: step 5980, loss 0.0422724, acc 1
#
#
# @chjluc91 @yomasterjon @richardtburnett scary how smoothly cruz looks into the camera and lies about trump cant be #potus #trump2016 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.317375: step 5980, loss 0.104911, acc 1
#
#
# im sick and tired of trump attacking my family this isnt about my family or his family its about your family #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.321973: step 5980, loss 0.111307, acc 1
#
#
# during last night’s #gopdebate i called out @realdonaldtrump he is not a true conservative watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.326685: step 5980, loss 0.0348195, acc 1
#
#
# @familyredsfans @foxnews is really starting to campaign hard for marcorubio #fairandbalancedmyass he is weak on illegal immigration <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.330750: step 5980, loss 0.0283284, acc 1
#
#
# weak jeb getting thrown out by management during speech do you think he will be this tough on putin others <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.336739: step 5980, loss 0.0942335, acc 1
#
#
# this election is about defeating hillary clinton and about saving what makes america unique <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.341057: step 5980, loss 1.0323, acc 0
#
#
# you know whats weak @realdonaldtrump disparaging women hispanics american heroes like john mccain #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.346141: step 5980, loss 0.00536384, acc 1
#
#
# lightweight @jebbush is spending a fortune of special interest against me in sc false advertising desperate and sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.350009: step 5980, loss 0.0168424, acc 1
#
#
# lying ted cruz and leightweight chocker marco rubio teamed up last night in a last ditch effort to stop our great movement they failed <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.353772: step 5980, loss 0.00762067, acc 1
#
#
# do you think @sentedcruz knows about @bobvanderplaats dealings actually i doubt it <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.358368: step 5980, loss 0.00821107, acc 1
#
#
# ted cruz is a cheater he holds the bible high and then lies and misrepresents the facts <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.362900: step 5980, loss 0.0213404, acc 1
#
#
# wow jeb bush whose campaign is a total disaster had to bring in mommy to take a slap at me not nice <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.367202: step 5980, loss 0.294024, acc 1
#
#
# while @realdonaldtrump was building a reality tv show my brother was keeping us safe #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.370863: step 5980, loss 0.0328257, acc 1
#
#
# @1sonny12 @ksmith233035 @mitchellvii floridians are upset because rubio did not do what he promised once he was elected vote trump <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.374587: step 5980, loss 0.00398698, acc 1
#
#
# why does @megynkelly devote so much time on her shows to me almost always negative without me her ratings would tank get a life megyn <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.378170: step 5980, loss 0.075546, acc 1
#
#
# disparaging women hispanics the disabled isnt a sign of strength its a sign of weakness @realdonaldtrump #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.381796: step 5980, loss 0.204009, acc 1
#
#
# leightweight chocker marco rubio looks like a little boy on stage not presidential material <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.385540: step 5980, loss 0.00318104, acc 1
#
#
# a big fat hit job on @oreillyfactor tonight a total waste of time to watch boring and biased @brithume said i would never run a dope <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.389215: step 5980, loss 0.0798526, acc 1
#
#
# even though every poll time drudge etc has me winning the debate by a lot @foxnews only puts negative people on biased  a total joke <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.393070: step 5980, loss 0.0267786, acc 1
#
#
# ted cruz lifts the bible high into the air and then lies like a dogover and over again the evangelicals in sc figured him out said no <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.398210: step 5980, loss 0.0794946, acc 1
#
#
# obama clinton should stop being dishonest admit their incrementalist isis strategy is failing <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.402154: step 5980, loss 0.0548017, acc 1
#
#
# appalling for @potus to legitimize the castro regime with a visit before freedom for cuban people watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.405983: step 5980, loss 3.39779, acc 0
#
#
# @realdonaldtrump chose his own personal gains over protecting an elderly widow’s home watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.410116: step 5980, loss 0.100121, acc 1
#
#
# obamas incremental and naïve foreign policy is not rooted in reality i will restore us leadership <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.419934: step 5980, loss 0.200588, acc 1
#
#
# big defeat last night in nevada for ted cruz and marco rubio @karlrove on @foxnews is working hard to belittle my victory rove is sick <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.425386: step 5980, loss 0.0424643, acc 1
#
#
# lying cruz put out a statement “trump rubio are w/obama on gay marriage cruz is the worst liar crazy or very dishonest perhaps all 3 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.434369: step 5980, loss 0.035864, acc 1
#
#
# donald trump can’t prosecute the case against hillary — he’s donated $100000 to her foundation we can’t lose to her in november #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.439096: step 5980, loss 0.0505173, acc 1
#
#
# @realdonaldtrump is no ronald reagan  not even close #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.459310: step 5980, loss 0.198716, acc 1
#
#
# now that bush has wasted $120 million of special interest money on his failed campaign he says he would end super pacs sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.468534: step 5980, loss 0.00219283, acc 1
#
#
# this shows what a complete total liar ted cruz is he said he wouldnt have nominated john roberts really <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.472915: step 5980, loss 0.00428271, acc 1
#
#
# @realdonaldtrump is not a serious candidate we’re living in serious times need a real commanderinchief <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.477405: step 5980, loss 0.132729, acc 1
#
#
# the statement put out yesterday by @foxnews was a disgrace to good broadcasting and journalism who would ever say something so nasty dumb <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.483146: step 5980, loss 0.0678298, acc 1
#
#
# abc news’ @jonkarl  “i have never seen christie tougher in this race i have never seen marco rubio more rattled” <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.487722: step 5980, loss 0.292598, acc 1
#
#
# @gene70 @fireflyfury @megynkelly @realdonaldtrump and this is the bimbo thats asking presidential questions <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.491697: step 5980, loss 0.306037, acc 1
#
#
# @foxnews is the only network that does not even mention my very successful event last night $6000000 raised in one hour for our vets <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.495564: step 5980, loss 0.254917, acc 1
#
#
# @foxnews is so biased it is disgusting they do not want trump to win all negative <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.499133: step 5980, loss 0.101786, acc 1
#
#
# @big_carsonrocks americastop being dupedwake up cruz rubio establishment phonies donaldtrump only truthful not owned candidate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.504665: step 5980, loss 0.065331, acc 1
#
#
# @autumnandews08 @realdonaldtrump @jebbush jeb is incompetent and will lose dont waste your energy on that cry baby <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.508174: step 5980, loss 0.0526444, acc 1
#
#
# @hollywoodjv @realdonaldtrump mr trump why does cruz hate canada so much he should embrace his roots its a great country so true <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.512489: step 5980, loss 0.00419843, acc 1
#
#
# jeb bush and ted cruz are not electable presidential candidates hillary would destroy them ted may not be eligible to run  born in canada <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.517673: step 5980, loss 0.0117852, acc 1
#
#
# vladimir putin is an opportunist hes a bully and we have to face him head on #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.522088: step 5980, loss 0.305849, acc 1
#
#
# lying ted cruz and lightweight choker marco rubio teamed up last night in a last ditch effort to stop our great movement they failed <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.527723: step 5980, loss 0.0134662, acc 1
#
#
# @tedcruz @marcorubio talk tough now but where were they when they had the chance to act on syria #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.536295: step 5980, loss 0.0287199, acc 1
#
#
# the great state of nebraska can do much better than @bensasse as your senator saw him on @greta  totally ineffective wants paid for pols <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.547510: step 5980, loss 0.0679872, acc 1
#
#
# senator @marcorubio acted like he was disembodied from the bill it was his bill #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.555711: step 5980, loss 0.00504044, acc 1
#
#
# all you do is win @realdonaldtrump really <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.564287: step 5980, loss 0.19327, acc 1
#
#
# mitt romneywho totally blew an election that should have been won and whose tax returns made him look like a fool is now playing tough guy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.570212: step 5980, loss 0.00304093, acc 1
#
#
# millions of $s of false ads paid for by lobbyistsspecial interests of cheater @sentedcruz and sleepy @jebbush are now running in sc <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.574080: step 5980, loss 0.0549861, acc 1
#
#
# @chatteringteef @borntobegop @realdonaldtrump @mittromney hates to see trumps success when he was so pathetic <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.578262: step 5980, loss 0.00127342, acc 1
#
#
# failed presidential candidate @mittromney was made to look like a fool by senator harry reid didnt release his tax returns until 9/21/12 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.582437: step 5980, loss 0.00786529, acc 1
#
#
# @trumpnewmedia why does ted cruz lie so much lets face it ted never created even 1 job his entire life #watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.586170: step 5980, loss 0.0171742, acc 1
#
#
# ted cruz has now apologized to marco rubio and ben carson for fraud and dirty tricks no wonder he has lost evangelical support <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.589744: step 5980, loss 0.00525735, acc 1
#
#
# it is appalling that @hillaryclinton insisted that minors be shipped back to their country of origin like a package marked return to sender <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.593410: step 5980, loss 0.0738771, acc 1
#
#
# lightweight choker marco rubio looks like a little boy on stage not presidential material <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.596870: step 5980, loss 0.019889, acc 1
#
#
# the president is obsessed with taxes his latest scheme would hit consumers to pay for even more govt spending <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.600389: step 5980, loss 0.67111, acc 1
#
#
# @by @tedcruz good i want to see the court decide what i was always told natural born means  born on american soil <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.604892: step 5980, loss 0.0775093, acc 1
#
#
# nyt agrees @hillaryclinton should release her wall street transcripts day 20 since she said i will look into it <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.608700: step 5980, loss 0.0199641, acc 1
#
#
# for your afternoon playlist we have a couple of @marcorubio classics from the album scripted <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.614296: step 5980, loss 0.0554033, acc 1
#
#
# amazing that ted cruz cant even get a senator like @bensasse who is easy to endorse him not one senator is endorsing canada ted <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.622682: step 5980, loss 0.0373113, acc 1
#
#
# @foxnews is changing their theme from fair and balanced to unfair and unbalanced but dying @wsj is worsetheir phony poll is a joke <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.627866: step 5980, loss 0.0397479, acc 1
#
#
# i will certainly look into it  @hillaryclinton voters deserve to know what she told wall street and big pharma behind closed doors <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.633383: step 5980, loss 0.111628, acc 1
#
#
# the sheer incompetence at the va is outrageous @hillaryclinton ignores it ill fix it #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.637376: step 5980, loss 0.0788441, acc 1
#
#
# donald trump isnt on stage at the #gopdebate—but you can bet the same backwards ideas and outoftouch rhetoric will be out in force <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.641206: step 5980, loss 1.16899, acc 0
#
#
# i refuse to call megyn kelly a bimbo because that would not be politically correct instead i will only call her a lightweight reporter <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.644936: step 5980, loss 0.205864, acc 1
#
#
# state department confirms @hillaryclinton looked us in the eye and lied <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.648522: step 5980, loss 0.342383, acc 1
#
#
# anybody who watched all of ted cruzs far too long rambling overly flamboyant speech last nite would say that was his howard dean moment <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.652512: step 5980, loss 0.00176036, acc 1
#
#
# ted cruz said on @oreillyfactor that illegals sent out of country by my administration would come right back as citizens another liecrazy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.656594: step 5980, loss 0.0524437, acc 1
#
#
# funny that jeb() didnt want help from his family in his failed campaign and didnt even want to use his last namethen mommy now brother <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.660674: step 5980, loss 0.00594787, acc 1
#
#
# if you can’t list one accomplishment by @marcorubio how do you know he has the leadership skills to be president <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.664805: step 5980, loss 0.126895, acc 1
#
#
# icymi i’m the only one who took on @realdonaldtrump exposed the flaws in his candidacy he is not a conservative <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.669149: step 5980, loss 0.007778, acc 1
#
#
# you know before it was called obamacare it was called hillarycare #demdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.673007: step 5980, loss 0.167068, acc 1
#
#
# greed fraud dishonesty arrogance these are just some of the adjectives we use to describe wall street <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.676335: step 5980, loss 0.0764046, acc 1
#
#
# if donald trump builds his wall the way he built trump tower he’ll be using illegal immigrant labor to do it #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.680487: step 5980, loss 0.0167653, acc 1
#
#
# if @tedcruz doesn’t clean up his act stop cheating doing negative ads i have standing to sue him for not being a natural born citizen <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.684130: step 5980, loss 0.0832021, acc 1
#
#
# just saw the phony ad by cruz  totally false more dirty tricks he got caught in so many lies  is this man crazy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.687794: step 5980, loss 0.00438941, acc 1
#
#
# @ahernandez85a @realdonaldtrump mr tough guy romney should be backing trump like trump backed him last time #noloyalty <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.691501: step 5980, loss 0.00643823, acc 1
#
#
# jeb used eminent domain took advantage of a disabled vet in the process (2/2) <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.694956: step 5980, loss 0.416803, acc 1
#
#
# cruz caught cold in lie after denial of push polls like lies w/ @realbencarson how can he preach christian values <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.698512: step 5980, loss 0.134922, acc 1
#
#
# jeb failed as jeb he gave up and enlisted mommy and his brother (who got us into the quicksand of iraq) spent $120 millionweakno chance <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.702015: step 5980, loss 0.0214736, acc 1
#
#
# ted cruz should be disqualified from his fraudulent win in iowa weak rnc and republican leadership probably wont let this happen sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.705618: step 5980, loss 0.62922, acc 1
#
#
# trump’s “record or lack thereof proves he is more of a proclinton democrat than a reagan republican @reaganworld <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.709326: step 5980, loss 0.0192889, acc 1
#
#
# @ward_ii oh great @mittromney is doing a @senatorreid on @realdonaldtrump like losing the presidency wasnt enough #trump2016 hes a fool <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.712946: step 5980, loss 0.0569475, acc 1
#
#
# @realdonaldtrump trembling at being questioned by @megynkelly channels monty python <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.716722: step 5980, loss 0.172174, acc 1
#
#
# @gigglemitz @geraldorivera @foxnews damn fox is really acting like a baby today i guess trump got under their skin  pretty biased <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.720667: step 5980, loss 0.0493303, acc 1
#
#
# asked about his record @marcorubio only gives general answers on how proud he was of his time as a public servant <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.724808: step 5980, loss 0.044707, acc 1
#
#
# thanks @meagy19 helps when you know what you stand for cc @marcorubio @tedcruz <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.729085: step 5980, loss 0.0335179, acc 1
#
#
# radical islamic jihadists want to impose their faith upon each and every one of us #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.734046: step 5980, loss 0.0810011, acc 1
#
#
# @hillaryclinton believes republicans should set the standard for disclosure of her wall street speeches aren’t we better than that <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.737660: step 5980, loss 0.0826949, acc 1
#
#
# at last nights #gopdebate i exposed donald trump for the con artist he is <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.741281: step 5980, loss 0.0522645, acc 1
#
#
# i will beat hillary easily but lindsey graham says i wont and yet he got zero against me no cred why does fox put him on <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.745217: step 5980, loss 0.0780542, acc 1
#
#
# ted cruz’s campaign spread false report in iowa that ben carson was quitting race <URL/> via @nytpolitics <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-01T17:25:13.748813: step 5980, loss 0.164274, acc 1
#
#
# ...
# nonexample
# 2016-03-01T17:25:14.623061: step 5980, loss 1.657e-05, acc 1
#
#
# these are the top national security priorities marco would address as president #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.627637: step 5980, loss 0.00279263, acc 1
#
#
# glad to join @chucktodd and @savannahguthrie this morning to speak about tonights #iacaucus <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.633860: step 5980, loss 5.96046e-07, acc 1
#
#
# we cannot mix radical muslim jihadists with every day muslims #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.652224: step 5980, loss 0.000854485, acc 1
#
#
# the lines are clear @marcorubio right now supports citizenship for 11 million people here illegally i oppose it #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.656596: step 5980, loss 0.000616003, acc 1
#
#
# watch the #gopdebate on 📺 @foxnews follow along online with us here 💻 <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.660323: step 5980, loss 6.62782e-05, acc 1
#
#
# we can reignite the promise of america and with your help we will join the #cruzcrew <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.663960: step 5980, loss 0, acc 1
#
#
# today im proud to release my plan on how we can destroy #isis read more <URL/> #carsonpolicy <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.667345: step 5980, loss 2.6226e-06, acc 1
#
#
# just as the united states opposed the spread of communism it must now oppose the spread of terrorism in all corners of the world <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.670872: step 5980, loss 6.55649e-06, acc 1
#
#
# the red hot @chilipeppers have a message for you <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.674337: step 5980, loss 0.000150908, acc 1
#
#
# we cant let republicans rip away @potus’ progress text imwithher to 47246 if you agree <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.678576: step 5980, loss 0.000143279, acc 1
#
#
# its outrageous that republicanshave already pledged to block any [supreme court] replacement that president obama nominates —hillary <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.681948: step 5980, loss 0.00111494, acc 1
#
#
# on the questions of life and marriage a record matters #goptownhall <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.686094: step 5980, loss 0.00178761, acc 1
#
#
# racism sexism and bigotry is not what this country is supposed to be about #bernieinsc <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.690515: step 5980, loss 2.62257e-05, acc 1
#
#
# black families are denied mortgages nearly 3x as often as white families we need to tear down barriers of systemic racism that still exist <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.694857: step 5980, loss 6.16293e-05, acc 1
#
#
# ✔️ wall street ✔️ pricegouging pharmaceutical companies ✔️ the gun lobby we will go after industries when they hurt families #demdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.698150: step 5980, loss 5.13779e-05, acc 1
#
#
# will be at fort worth (texas) convention center at 1130 am big crowd  get there early big announcement to be made <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.710573: step 5980, loss 0.000156629, acc 1
#
#
# america’s most urgent foreign policy priority should be to defeat and destroy radical islamic terrorism <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.716169: step 5980, loss 0.0017919, acc 1
#
#
# if i am elected president we will not be drafting our daughters into combat #goptownhall <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.722351: step 5980, loss 4.29153e-06, acc 1
#
#
# thank you baton rouge louisiana we will #makeamericagreatagain #trump2016 <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.726534: step 5980, loss 3.81469e-06, acc 1
#
#
# i am not a singleissue candidate and i do not believe we live in a singleissue country #demdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.729916: step 5980, loss 1.54972e-06, acc 1
#
#
# #cruzcrew tune in to tonights #gopdebate on fox news​ at 9 pm et <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.733555: step 5980, loss 1.54971e-05, acc 1
#
#
# salem nh bring your friends family and neighbors to #choosecruz on 2/9 <URL/> #fitn #nhpolitics <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.737637: step 5980, loss 1.19209e-06, acc 1
#
#
# during this #gopdebate commercial break just a reminder to follow along with us on our live blog <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.741605: step 5980, loss 0.000144352, acc 1
#
#
# new fox news debate video i will unify the republican party defeat hillary clinton <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.745964: step 5980, loss 0.000421197, acc 1
#
#
# this is it—the #iowacaucus is today if you’re standing with hillary rt to say #imwithher <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.751025: step 5980, loss 3.24244e-05, acc 1
#
#
# need to look up your polling location <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.755443: step 5980, loss 6.6757e-06, acc 1
#
#
# hillary on the flint water crisis would it have happened if they were rich and white instead of poor and black #nhdems2016 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.760504: step 5980, loss 0.000102992, acc 1
#
#
# @mikeliberation this is the best reaction shot ive ever seen lol #trump2016 <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.764306: step 5980, loss 0.0001018, acc 1
#
#
# last night we served notice to the political and economic establishment of this country the people want real change <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.767920: step 5980, loss 1.54972e-06, acc 1
#
#
# nevada if youre in line stay there—and talk to your neighbors about hillary <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.771748: step 5980, loss 5.44772e-05, acc 1
#
#
# team jeb taking over follow along with us during the #gopdebate here → <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.775521: step 5980, loss 0.000443599, acc 1
#
#
# we must stop making our political process about spectacle and must instead make it about the future of our nation <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.779041: step 5980, loss 1.19209e-07, acc 1
#
#
# americans dont care about who is establishment or who is grassroots #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.782501: step 5980, loss 0.000849601, acc 1
#
#
# @rbreich like #jimmycarter says im more dangerous to leftists bc i actually believe in the constitution true <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.786652: step 5980, loss 0.000174746, acc 1
#
#
# in 93 hours it’ll be time for iowans to decide i’d be honored if you would caucus for me on monday night #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.789733: step 5980, loss 2.61065e-05, acc 1
#
#
# millions of families like karla’s live in fear of deportation we need a president who will fight to protect them <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.796174: step 5980, loss 4.76836e-06, acc 1
#
#
# no one can get this done alone—not even the president of the united states it’s got to be the mission of our entire nation <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.799662: step 5980, loss 4.41073e-06, acc 1
#
#
# more proof that women need a president who will stop attacks on womens health in their tracks <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.805756: step 5980, loss 1.3113e-06, acc 1
#
#
# thank you plymouth new hampshire #fitn #nhprimary <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.809963: step 5980, loss 1.07288e-06, acc 1
#
#
# join me tomorrow in plymouth new hampshire #fitn #nhprimary <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.814110: step 5980, loss 3.57628e-07, acc 1
#
#
# a consistent conservative record of accomplishments vs …nothing <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.820697: step 5980, loss 0.000280579, acc 1
#
#
# heres an easy way to help hillary win in new hampshire—it only takes 5 minutes <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.824557: step 5980, loss 1.44242e-05, acc 1
#
#
# thank you nevada we will make america safe great again <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.828514: step 5980, loss 0, acc 1
#
#
# our newest tv ad highlights the most important part of my life my family <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.833225: step 5980, loss 1.46626e-05, acc 1
#
#
# ben carson picks up endorsement reveals plan to care for veterans  breitbart <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.838234: step 5980, loss 4.68482e-05, acc 1
#
#
# in 2015 @simone_biles leapt into record books as the worlds most decorated woman gymnast <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.841707: step 5980, loss 3.13516e-05, acc 1
#
#
# totally unauthorized do not pay i am self funding my campaign notice has just been withdrawn #trump2016 #makeamericagreatagain <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.847715: step 5980, loss 2.0623e-05, acc 1
#
#
# show marco youre on the team chip in $5 right now right from twitter <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.854195: step 5980, loss 4.64915e-06, acc 1
#
#
# we had awesome crowds at our two town halls in spartanburg and columbia today <URL/> #scformarco <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.860720: step 5980, loss 3.21865e-06, acc 1
#
#
# @godownswingin glad to have you on our team thanks for the support <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.864307: step 5980, loss 4.17232e-06, acc 1
#
#
# 29 million americans don’t have health insurance 31 million are underinsured that’s rationing those are wait times #demtownhall <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.867997: step 5980, loss 0.00082709, acc 1
#
#
# standing room only in mount pleasant thank you all <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.871601: step 5980, loss 3.57627e-06, acc 1
#
#
# couldnt agree more @iamsteveharvey its time to act on gun violence thank you for telling these stories today <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.875580: step 5980, loss 2.25303e-05, acc 1
#
#
# the puerto rican senate just confirmed maite oronoz rodríguez making her the first lgbt chief justice in the us <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.879593: step 5980, loss 5.00678e-06, acc 1
#
#
# listen to why charlie is supporting our campaign #fits #choosecruz join him <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.883172: step 5980, loss 2.02656e-06, acc 1
#
#
# i will be interviewed from charleston south carolina by @joenbc and @morningmika at 8pm tonight for one hour on @msnbc enjoy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.887229: step 5980, loss 7.62937e-06, acc 1
#
#
# sorry to miss you but glad you got to meet @heidiscruz <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-01T17:25:14.890663: step 5980, loss 2.8133e-05, acc 1
