# %% [markdown]
# # Notebook 2: CNN
#
# ## Overview:
#
# 1. Begin by importing and getting the embeddings and word to index mappings we created in [Notebook 1: Embed Words](Notebook_1_Embed_Words.ipynb)

# %%
# Parameters
# ==================================================

# Model Hyperparameters
embedding_dim = 20  #Dimensionality of character embedding (default: 128)
filter_sizes =  "3,4,5" #"Comma-separated filter sizes (default: '3,4,5')")
num_filters = 50  #"Number of filters per filter size (default: 128)")
dropout_keep_prob = 0.5 #"Dropout keep probability (default: 0.5)")
l2_reg_lambda = 3.0 #"L2 regularizaion lambda (default: 0.0)")

# Training parameters
batch_size = 64 # "Batch Size (default: 64)")
num_epochs = 500 #"Number of training epochs (default: 200)")
evaluate_every = 100  #"Evaluate model on dev set after this many steps (default: 100)")
checkpoint_every = 100 # "Save model after this many steps (default: 100)")
# Misc Parameters
allow_soft_placement = True # "Allow device soft device placement")
log_device_placement = False  #"Log placement of ops on devices")
display_train_steps = False # toggles output of training step results

# %%
import cPickle as pickle
from tensorflow.models.rnn.rnn_cell import BasicLSTMCell, LSTMCell 
import itertools
from collections import Counter
import csv
import re
import numpy as np
import string

# %%
embeddings = None
mappings = None
rows = None

with open("word_embeddings.pkl", "rb") as f:
    embeddings = pickle.load(f)
with open("word_mappings.pkl", "rb") as f:
    mappings = pickle.load(f)
    

urlFinder = re.compile('\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*')
atNameFinder = re.compile(r'@([A-Za-z0-9_]+)')
atNameCounter = 0

exclude_punc = set([
        "!",
        "?",
        ".",
        ",",
        ":",
        ";",
        "'",
        "\"",
        "“",
        "’",
        "-"
])

sentences = []
labels = []
x = []
y = []
_y = []

with open('data.csv', 'rb') as f:
    reader = csv.reader(f, delimiter=',')   
    
    for row in reader:
        words = []
        
        for word in row[1] \
            .strip() \
            .replace("&amp;", "") \
            .replace("&gt;","") \
            .replace("&lt;", "") \
            .lower().split():
            
            if urlFinder.match(word):
                words.append("<URL/>")
            elif atNameFinder.search(word):
                words.append("<AT_NAME/>")
                atNameCounter +=1
            else:
                word = ''.join(ch for ch in word if ch not in exclude_punc)
                words.append(word)
        sentences.append(words)
        labels.append(([0, 1] if row[0] == "example" else [1, 0]))
        _y.append(1 if row[0] == "example" else 0)


sequence_length = max(len(i) for i in sentences)
padded_sentences = []
for i in range(len(sentences)):
    sentence = sentences[i]
    num_padding = sequence_length - len(sentence)
    new_sentence = sentence + ["<PAD/>"] * num_padding
    padded_sentences.append(new_sentence)
    
 
word_counts = Counter(itertools.chain(*padded_sentences))

# Mapping from index to word
vocabulary_inv = [x[0] for x in word_counts.most_common()]
# Mapping from word to index
vocabulary = {x: i for i, x in enumerate(vocabulary_inv)}

x = np.array([[vocabulary[word] for word in sentence] for sentence in padded_sentences])
y = np.array(labels)

# %%
import tensorflow as tf
import numpy as np


class TextCNN(object):
    """
    A CNN for text classification.
    Uses an embedding layer, followed by a convolutional, max-pooling and softmax layer.
    """
    def __init__(
      self, sequence_length, num_classes, vocab_size,
      embedding_size, filter_sizes, num_filters, l2_reg_lambda=0.0):

        # Placeholders for input, output and dropout
        self.input_x = tf.placeholder(tf.int32, [None, sequence_length], name="input_x")
        self.input_y = tf.placeholder(tf.float32, [None, num_classes], name="input_y")
        self.dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")

        # Keeping track of l2 regularization loss (optional)
        l2_loss = tf.constant(0.0)

        # Embedding layer
        with tf.device('/cpu:0'), tf.name_scope("embedding"):
            W = tf.Variable(
                tf.random_uniform([vocab_size, embedding_size], -1.0, 1.0),
                name="W")
            self.embedded_chars = tf.nn.embedding_lookup(W, self.input_x)
            self.embedded_chars_expanded = tf.expand_dims(self.embedded_chars, -1)

        # Create a convolution + maxpool layer for each filter size
        pooled_outputs = []
        for i, filter_size in enumerate(filter_sizes):
            with tf.name_scope("conv-maxpool-%s" % filter_size):
                # Convolution Layer
                filter_shape = [filter_size, embedding_size, 1, num_filters]
                W = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W")
                b = tf.Variable(tf.constant(0.1, shape=[num_filters]), name="b")
                conv = tf.nn.conv2d(
                    self.embedded_chars_expanded,
                    W,
                    strides=[1, 1, 1, 1],
                    padding="VALID",
                    name="conv")
                # Apply nonlinearity
                h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                # Maxpooling over the outputs
                pooled = tf.nn.max_pool(
                    h,
                    ksize=[1, sequence_length - filter_size + 1, 1, 1],
                    strides=[1, 1, 1, 1],
                    padding='VALID',
                    name="pool")
                pooled_outputs.append(pooled)

        # Combine all the pooled features
        num_filters_total = num_filters * len(filter_sizes)
        self.h_pool = tf.concat(3, pooled_outputs)
        self.h_pool_flat = tf.reshape(self.h_pool, [-1, num_filters_total])

        # Add dropout
        with tf.name_scope("dropout"):
            self.h_drop = tf.nn.dropout(self.h_pool_flat, self.dropout_keep_prob)

        # Final (unnormalized) scores and predictions
        with tf.name_scope("output"):
            W = tf.Variable(tf.truncated_normal([num_filters_total, num_classes], stddev=0.1), name="W")
            b = tf.Variable(tf.constant(0.1, shape=[num_classes]), name="b")
            l2_loss += tf.nn.l2_loss(W)
            l2_loss += tf.nn.l2_loss(b)
            self.scores = tf.nn.xw_plus_b(self.h_drop, W, b, name="scores")
            self.predictions = tf.argmax(self.scores, 1, name="predictions")

        # CalculateMean cross-entropy loss
        with tf.name_scope("loss"):
            losses = tf.nn.softmax_cross_entropy_with_logits(self.scores, self.input_y)
            self.loss = tf.reduce_mean(losses) + l2_reg_lambda * l2_loss

        # Accuracy
        with tf.name_scope("accuracy"):
            correct_predictions = tf.equal(self.predictions, tf.argmax(self.input_y, 1))
            self.accuracy = tf.reduce_mean(tf.cast(correct_predictions, "float"), name="accuracy")

# %%
def batch_iter(data, batch_size, num_epochs):
    """
    Generates a batch iterator for a dataset.
    """
    data = np.array(data)
    data_size = len(data)
    num_batches_per_epoch = int(len(data)/batch_size) + 1
    for epoch in range(num_epochs):
        # Shuffle the data at each epoch
        shuffle_indices = np.random.permutation(np.arange(data_size))
        shuffled_data = data[shuffle_indices]
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, data_size)
            yield shuffled_data[start_index:end_index]

# %%
import tensorflow as tf
import numpy as np
import os
import time
import datetime
from sklearn.cross_validation import StratifiedShuffleSplit


# Data Preparatopn
# ==================================================

# Load data
print("Loading data...")
# Randomly shuffle data
sss = StratifiedShuffleSplit(_y, 1, test_size=0.5, random_state=0)
for train, test in sss:
    x_train = x[train]
    y_train = y[train]

    x_dev = x[test]
    y_dev = y[test]

# Training
# ==================================================


with tf.Graph().as_default():
    session_conf = tf.ConfigProto(
      allow_soft_placement=allow_soft_placement,
      log_device_placement=log_device_placement)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        cnn = TextCNN(
            sequence_length=x_train.shape[1],
            num_classes=2,
            vocab_size=len(vocabulary),
            embedding_size=embedding_dim,
            filter_sizes=map(int, filter_sizes.split(",")),
            num_filters=num_filters,
            l2_reg_lambda=l2_reg_lambda)

        # Define Training procedure
        global_step = tf.Variable(0, name="global_step", trainable=False)
        optimizer = tf.train.AdamOptimizer(1e-4)
        grads_and_vars = optimizer.compute_gradients(cnn.loss)
        train_op = optimizer.apply_gradients(grads_and_vars, global_step=global_step)

        # Keep track of gradient values and sparsity (optional)
        grad_summaries = []
        for g, v in grads_and_vars:
            if g is not None:
                grad_hist_summary = tf.histogram_summary("{}/grad/hist".format(v.name), g)
                sparsity_summary = tf.scalar_summary("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                grad_summaries.append(grad_hist_summary)
                grad_summaries.append(sparsity_summary)
        grad_summaries_merged = tf.merge_summary(grad_summaries)

        # Output directory for models and summaries
        timestamp = str(int(time.time()))
        out_dir = os.path.abspath(os.path.join(os.path.curdir, "runs", timestamp))
        print("Writing to {}\n".format(out_dir))

        # Summaries for loss and accuracy
        loss_summary = tf.scalar_summary("loss", cnn.loss)
        acc_summary = tf.scalar_summary("accuracy", cnn.accuracy)

        # Train Summaries
        train_summary_op = tf.merge_summary([loss_summary, acc_summary, grad_summaries_merged])
        train_summary_dir = os.path.join(out_dir, "summaries", "train")
        train_summary_writer = tf.train.SummaryWriter(train_summary_dir, sess.graph_def)

        # Dev summaries
        dev_summary_op = tf.merge_summary([loss_summary, acc_summary])
        dev_summary_dir = os.path.join(out_dir, "summaries", "dev")
        dev_summary_writer = tf.train.SummaryWriter(dev_summary_dir, sess.graph_def)

        # Checkpoint directory. Tensorflow assumes this directory already exists so we need to create it
        checkpoint_dir = os.path.abspath(os.path.join(out_dir, "checkpoints"))
        checkpoint_prefix = os.path.join(checkpoint_dir, "model")
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        saver = tf.train.Saver(tf.all_variables())

        # Initialize all variables
        sess.run(tf.initialize_all_variables())

        def train_step(x_batch, y_batch):
            """
            A single training step
            """
            feed_dict = {
              cnn.input_x: x_batch,
              cnn.input_y: y_batch,
              cnn.dropout_keep_prob: dropout_keep_prob
            }
            _, step, summaries, loss, accuracy = sess.run(
                [train_op, global_step, train_summary_op, cnn.loss, cnn.accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            if(display_train_steps):
                print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
            train_summary_writer.add_summary(summaries, step)

        def dev_step(x_batch, y_batch, writer=None):
            """
            Evaluates model on a dev set
            """
            feed_dict = {
              cnn.input_x: x_batch,
              cnn.input_y: y_batch,
              cnn.dropout_keep_prob: 1.0
            }
            step, summaries, loss, accuracy = sess.run(
                [global_step, dev_summary_op, cnn.loss, cnn.accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
            if writer:
                writer.add_summary(summaries, step)
            return accuracy

        # Generate batches
        batches = batch_iter(
            zip(x_train, y_train), batch_size, num_epochs)
        # Training loop. For each batch...
        for batch in batches:
            x_batch, y_batch = zip(*batch)
            train_step(x_batch, y_batch)
            current_step = tf.train.global_step(sess, global_step)
            if current_step % evaluate_every == 0:
                print("\nEvaluation:")
                dev_step(x_dev, y_dev, writer=dev_summary_writer)
                print("")
            if current_step % checkpoint_every == 0:
                path = saver.save(sess, checkpoint_prefix, global_step=current_step)
                print("Saved model checkpoint to {}\n".format(path))
        
        print("\nFinal Evaluations:")
        dev_step(x_dev, y_dev, writer=dev_summary_writer)
  
        
        print("")
# Out:
# Loading data...
# Writing to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890
#
#
# Evaluation:
# 2016-03-11T16:14:57.195108: step 100, loss 3.27064, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-100
#
#
# Evaluation:
# 2016-03-11T16:15:02.994958: step 200, loss 2.77174, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-200
#
#
# Evaluation:
# 2016-03-11T16:15:08.605686: step 300, loss 2.35955, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-300
#
#
# Evaluation:
# 2016-03-11T16:15:14.245227: step 400, loss 2.0146, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-400
#
#
# Evaluation:
# 2016-03-11T16:15:20.118417: step 500, loss 1.7291, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-500
#
#
# Evaluation:
# 2016-03-11T16:15:26.269179: step 600, loss 1.4914, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-600
#
#
# Evaluation:
# 2016-03-11T16:15:32.305190: step 700, loss 1.29455, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-700
#
#
# Evaluation:
# 2016-03-11T16:15:38.577720: step 800, loss 1.13068, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-800
#
#
# Evaluation:
# 2016-03-11T16:15:44.218114: step 900, loss 0.995029, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-900
#
#
# Evaluation:
# 2016-03-11T16:15:50.147056: step 1000, loss 0.883574, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1000
#
#
# Evaluation:
# 2016-03-11T16:15:55.767139: step 1100, loss 0.792049, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1100
#
#
# Evaluation:
# 2016-03-11T16:16:01.552048: step 1200, loss 0.717175, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1200
#
#
# Evaluation:
# 2016-03-11T16:16:07.206358: step 1300, loss 0.655463, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1300
#
#
# Evaluation:
# 2016-03-11T16:16:12.996790: step 1400, loss 0.605026, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1400
#
#
# Evaluation:
# 2016-03-11T16:16:18.702665: step 1500, loss 0.564469, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1500
#
#
# Evaluation:
# 2016-03-11T16:16:24.429268: step 1600, loss 0.531202, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1600
#
#
# Evaluation:
# 2016-03-11T16:16:30.114062: step 1700, loss 0.504652, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1700
#
#
# Evaluation:
# 2016-03-11T16:16:35.988941: step 1800, loss 0.483415, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1800
#
#
# Evaluation:
# 2016-03-11T16:16:41.808316: step 1900, loss 0.466078, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-1900
#
#
# Evaluation:
# 2016-03-11T16:16:48.025249: step 2000, loss 0.452139, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2000
#
#
# Evaluation:
# 2016-03-11T16:16:53.969533: step 2100, loss 0.440901, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2100
#
#
# Evaluation:
# 2016-03-11T16:16:59.993924: step 2200, loss 0.431894, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2200
#
#
# Evaluation:
# 2016-03-11T16:17:06.139989: step 2300, loss 0.424674, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2300
#
#
# Evaluation:
# 2016-03-11T16:17:12.145100: step 2400, loss 0.418882, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2400
#
#
# Evaluation:
# 2016-03-11T16:17:18.276325: step 2500, loss 0.414435, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2500
#
#
# Evaluation:
# 2016-03-11T16:17:24.133784: step 2600, loss 0.410875, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2600
#
#
# Evaluation:
# 2016-03-11T16:17:30.419628: step 2700, loss 0.40786, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2700
#
#
# Evaluation:
# 2016-03-11T16:17:36.136507: step 2800, loss 0.405323, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2800
#
#
# Evaluation:
# 2016-03-11T16:17:41.919512: step 2900, loss 0.403417, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-2900
#
#
# Evaluation:
# 2016-03-11T16:17:47.540197: step 3000, loss 0.401471, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3000
#
#
# Evaluation:
# 2016-03-11T16:17:53.322318: step 3100, loss 0.400156, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3100
#
#
# Evaluation:
# 2016-03-11T16:17:58.979017: step 3200, loss 0.398918, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3200
#
#
# Evaluation:
# 2016-03-11T16:18:04.707930: step 3300, loss 0.397756, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3300
#
#
# Evaluation:
# 2016-03-11T16:18:10.344814: step 3400, loss 0.396756, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3400
#
#
# Evaluation:
# 2016-03-11T16:18:16.075339: step 3500, loss 0.39589, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3500
#
#
# Evaluation:
# 2016-03-11T16:18:21.646932: step 3600, loss 0.394849, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3600
#
#
# Evaluation:
# 2016-03-11T16:18:27.410354: step 3700, loss 0.393899, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3700
#
#
# Evaluation:
# 2016-03-11T16:18:33.215183: step 3800, loss 0.393216, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3800
#
#
# Evaluation:
# 2016-03-11T16:18:39.174411: step 3900, loss 0.392341, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-3900
#
#
# Evaluation:
# 2016-03-11T16:18:45.054665: step 4000, loss 0.39226, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4000
#
#
# Evaluation:
# 2016-03-11T16:18:51.111911: step 4100, loss 0.390766, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4100
#
#
# Evaluation:
# 2016-03-11T16:18:57.052327: step 4200, loss 0.390163, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4200
#
#
# Evaluation:
# 2016-03-11T16:19:03.235602: step 4300, loss 0.389439, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4300
#
#
# Evaluation:
# 2016-03-11T16:19:09.167091: step 4400, loss 0.388865, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4400
#
#
# Evaluation:
# 2016-03-11T16:19:15.396645: step 4500, loss 0.388079, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4500
#
#
# Evaluation:
# 2016-03-11T16:19:21.345169: step 4600, loss 0.387502, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4600
#
#
# Evaluation:
# 2016-03-11T16:19:27.505304: step 4700, loss 0.386344, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4700
#
#
# Evaluation:
# 2016-03-11T16:19:33.299752: step 4800, loss 0.385492, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4800
#
#
# Evaluation:
# 2016-03-11T16:19:38.979820: step 4900, loss 0.385088, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-4900
#
#
# Evaluation:
# 2016-03-11T16:19:44.797442: step 5000, loss 0.384003, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5000
#
#
# Evaluation:
# 2016-03-11T16:19:50.385874: step 5100, loss 0.38313, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5100
#
#
# Evaluation:
# 2016-03-11T16:19:56.199693: step 5200, loss 0.382432, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5200
#
#
# Evaluation:
# 2016-03-11T16:20:01.804895: step 5300, loss 0.381544, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5300
#
#
# Evaluation:
# 2016-03-11T16:20:07.512388: step 5400, loss 0.380802, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5400
#
#
# Evaluation:
# 2016-03-11T16:20:13.165425: step 5500, loss 0.381007, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5500
#
#
# Evaluation:
# 2016-03-11T16:20:18.970587: step 5600, loss 0.379361, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5600
#
#
# Evaluation:
# 2016-03-11T16:20:24.559612: step 5700, loss 0.378728, acc 0.854792
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5700
#
#
# Evaluation:
# 2016-03-11T16:20:30.313949: step 5800, loss 0.377387, acc 0.855615
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5800
#
#
# Evaluation:
# 2016-03-11T16:20:36.308619: step 5900, loss 0.376784, acc 0.856026
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-5900
#
#
# Evaluation:
# 2016-03-11T16:20:42.323890: step 6000, loss 0.375891, acc 0.858083
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6000
#
#
# Evaluation:
# 2016-03-11T16:20:48.257362: step 6100, loss 0.375439, acc 0.857672
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6100
#
#
# Evaluation:
# 2016-03-11T16:20:54.399019: step 6200, loss 0.37451, acc 0.858494
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6200
#
#
# Evaluation:
# 2016-03-11T16:21:00.441671: step 6300, loss 0.373634, acc 0.86014
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6300
#
#
# Evaluation:
# 2016-03-11T16:21:06.469955: step 6400, loss 0.373231, acc 0.86014
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6400
#
#
# Evaluation:
# 2016-03-11T16:21:12.379488: step 6500, loss 0.372373, acc 0.860551
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6500
#
#
# Evaluation:
# 2016-03-11T16:21:18.370534: step 6600, loss 0.371857, acc 0.861374
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6600
#
#
# Evaluation:
# 2016-03-11T16:21:23.456310: step 6700, loss 0.370984, acc 0.862197
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6700
#
#
# Evaluation:
# 2016-03-11T16:21:28.701658: step 6800, loss 0.370713, acc 0.861785
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6800
#
#
# Evaluation:
# 2016-03-11T16:21:33.783986: step 6900, loss 0.369902, acc 0.863431
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-6900
#
#
# Evaluation:
# 2016-03-11T16:21:38.958527: step 7000, loss 0.369741, acc 0.863842
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7000
#
#
# Evaluation:
# 2016-03-11T16:21:43.984806: step 7100, loss 0.368417, acc 0.864665
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7100
#
#
# Evaluation:
# 2016-03-11T16:21:49.177361: step 7200, loss 0.367753, acc 0.865076
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7200
#
#
# Evaluation:
# 2016-03-11T16:21:54.304297: step 7300, loss 0.367133, acc 0.86631
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7300
#
#
# Evaluation:
# 2016-03-11T16:21:59.645109: step 7400, loss 0.366095, acc 0.867133
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7400
#
#
# Evaluation:
# 2016-03-11T16:22:04.678773: step 7500, loss 0.365347, acc 0.868367
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7500
#
#
# Evaluation:
# 2016-03-11T16:22:09.684980: step 7600, loss 0.364982, acc 0.868367
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7600
#
#
# Evaluation:
# 2016-03-11T16:22:14.971717: step 7700, loss 0.364936, acc 0.868367
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7700
#
#
# Evaluation:
# 2016-03-11T16:22:20.054996: step 7800, loss 0.364128, acc 0.86919
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7800
#
#
# Evaluation:
# 2016-03-11T16:22:25.251369: step 7900, loss 0.363706, acc 0.869601
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-7900
#
#
# Evaluation:
# 2016-03-11T16:22:30.360056: step 8000, loss 0.3625, acc 0.868778
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8000
#
#
# Evaluation:
# 2016-03-11T16:22:35.626689: step 8100, loss 0.361714, acc 0.86919
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8100
#
#
# Evaluation:
# 2016-03-11T16:22:40.789326: step 8200, loss 0.36135, acc 0.868367
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8200
#
#
# Evaluation:
# 2016-03-11T16:22:46.068484: step 8300, loss 0.361092, acc 0.868778
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8300
#
#
# Evaluation:
# 2016-03-11T16:22:51.190880: step 8400, loss 0.360309, acc 0.868778
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8400
#
#
# Evaluation:
# 2016-03-11T16:22:56.429196: step 8500, loss 0.360183, acc 0.868367
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8500
#
#
# Evaluation:
# 2016-03-11T16:23:01.552701: step 8600, loss 0.360174, acc 0.867956
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8600
#
#
# Evaluation:
# 2016-03-11T16:23:06.789303: step 8700, loss 0.36033, acc 0.868367
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8700
#
#
# Evaluation:
# 2016-03-11T16:23:12.014797: step 8800, loss 0.358388, acc 0.86919
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8800
#
#
# Evaluation:
# 2016-03-11T16:23:17.228845: step 8900, loss 0.358403, acc 0.871246
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-8900
#
#
# Evaluation:
# 2016-03-11T16:23:22.376867: step 9000, loss 0.35795, acc 0.870835
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9000
#
#
# Evaluation:
# 2016-03-11T16:23:27.562026: step 9100, loss 0.360398, acc 0.869601
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9100
#
#
# Evaluation:
# 2016-03-11T16:23:32.661823: step 9200, loss 0.356204, acc 0.871246
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9200
#
#
# Evaluation:
# 2016-03-11T16:23:37.895234: step 9300, loss 0.356044, acc 0.870424
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9300
#
#
# Evaluation:
# 2016-03-11T16:23:43.006109: step 9400, loss 0.355663, acc 0.870835
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9400
#
#
# Evaluation:
# 2016-03-11T16:23:48.176729: step 9500, loss 0.356183, acc 0.870835
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9500
#
#
# Evaluation:
# 2016-03-11T16:23:53.379812: step 9600, loss 0.355879, acc 0.872069
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9600
#
#
# Evaluation:
# 2016-03-11T16:23:58.658657: step 9700, loss 0.355174, acc 0.869601
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9700
#
#
# Evaluation:
# 2016-03-11T16:24:03.866883: step 9800, loss 0.354728, acc 0.872069
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9800
#
#
# Evaluation:
# 2016-03-11T16:24:09.122435: step 9900, loss 0.354129, acc 0.87248
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-9900
#
#
# Evaluation:
# 2016-03-11T16:24:14.363893: step 10000, loss 0.354611, acc 0.872892
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10000
#
#
# Evaluation:
# 2016-03-11T16:24:19.560321: step 10100, loss 0.354384, acc 0.87248
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10100
#
#
# Evaluation:
# 2016-03-11T16:24:24.655239: step 10200, loss 0.353899, acc 0.87248
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10200
#
#
# Evaluation:
# 2016-03-11T16:24:29.784775: step 10300, loss 0.353384, acc 0.873303
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10300
#
#
# Evaluation:
# 2016-03-11T16:24:34.968049: step 10400, loss 0.353913, acc 0.872069
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10400
#
#
# Evaluation:
# 2016-03-11T16:24:40.107801: step 10500, loss 0.353253, acc 0.873303
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10500
#
#
# Evaluation:
# 2016-03-11T16:24:45.348412: step 10600, loss 0.352754, acc 0.873303
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10600
#
#
# Evaluation:
# 2016-03-11T16:24:50.409723: step 10700, loss 0.351346, acc 0.876183
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10700
#
#
# Evaluation:
# 2016-03-11T16:24:55.609842: step 10800, loss 0.353937, acc 0.874126
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10800
#
#
# Evaluation:
# 2016-03-11T16:25:00.771875: step 10900, loss 0.35153, acc 0.874537
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-10900
#
#
# Evaluation:
# 2016-03-11T16:25:06.013034: step 11000, loss 0.353293, acc 0.875771
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11000
#
#
# Evaluation:
# 2016-03-11T16:25:11.134443: step 11100, loss 0.352061, acc 0.874126
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11100
#
#
# Evaluation:
# 2016-03-11T16:25:16.372215: step 11200, loss 0.35097, acc 0.874949
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11200
#
#
# Evaluation:
# 2016-03-11T16:25:21.648652: step 11300, loss 0.351807, acc 0.87536
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11300
#
#
# Evaluation:
# 2016-03-11T16:25:27.065157: step 11400, loss 0.350907, acc 0.875771
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11400
#
#
# Evaluation:
# 2016-03-11T16:25:32.238414: step 11500, loss 0.350501, acc 0.876594
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11500
#
#
# Evaluation:
# 2016-03-11T16:25:37.502559: step 11600, loss 0.348803, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11600
#
#
# Evaluation:
# 2016-03-11T16:25:42.686484: step 11700, loss 0.350035, acc 0.877417
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11700
#
#
# Evaluation:
# 2016-03-11T16:25:47.915651: step 11800, loss 0.352161, acc 0.876594
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11800
#
#
# Evaluation:
# 2016-03-11T16:25:53.088275: step 11900, loss 0.349266, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-11900
#
#
# Evaluation:
# 2016-03-11T16:25:58.282767: step 12000, loss 0.350187, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12000
#
#
# Evaluation:
# 2016-03-11T16:26:03.420834: step 12100, loss 0.350359, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12100
#
#
# Evaluation:
# 2016-03-11T16:26:08.579145: step 12200, loss 0.349581, acc 0.876594
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12200
#
#
# Evaluation:
# 2016-03-11T16:26:13.768593: step 12300, loss 0.348341, acc 0.876183
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12300
#
#
# Evaluation:
# 2016-03-11T16:26:19.035953: step 12400, loss 0.34795, acc 0.876594
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12400
#
#
# Evaluation:
# 2016-03-11T16:26:24.182485: step 12500, loss 0.348096, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12500
#
#
# Evaluation:
# 2016-03-11T16:26:29.443237: step 12600, loss 0.349182, acc 0.876183
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12600
#
#
# Evaluation:
# 2016-03-11T16:26:34.641145: step 12700, loss 0.346931, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12700
#
#
# Evaluation:
# 2016-03-11T16:26:40.592613: step 12800, loss 0.348797, acc 0.879473
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12800
#
#
# Evaluation:
# 2016-03-11T16:26:46.572546: step 12900, loss 0.348894, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-12900
#
#
# Evaluation:
# 2016-03-11T16:26:52.603510: step 13000, loss 0.350262, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13000
#
#
# Evaluation:
# 2016-03-11T16:26:58.613427: step 13100, loss 0.347916, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13100
#
#
# Evaluation:
# 2016-03-11T16:27:04.599816: step 13200, loss 0.34711, acc 0.876594
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13200
#
#
# Evaluation:
# 2016-03-11T16:27:10.259514: step 13300, loss 0.346786, acc 0.877417
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13300
#
#
# Evaluation:
# 2016-03-11T16:27:15.843460: step 13400, loss 0.34859, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13400
#
#
# Evaluation:
# 2016-03-11T16:27:21.552107: step 13500, loss 0.348588, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13500
#
#
# Evaluation:
# 2016-03-11T16:27:27.157867: step 13600, loss 0.34716, acc 0.876183
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13600
#
#
# Evaluation:
# 2016-03-11T16:27:32.918122: step 13700, loss 0.347558, acc 0.876594
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13700
#
#
# Evaluation:
# 2016-03-11T16:27:38.549777: step 13800, loss 0.346511, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13800
#
#
# Evaluation:
# 2016-03-11T16:27:44.281565: step 13900, loss 0.345551, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-13900
#
#
# Evaluation:
# 2016-03-11T16:27:49.934394: step 14000, loss 0.348912, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14000
#
#
# Evaluation:
# 2016-03-11T16:27:55.628618: step 14100, loss 0.351561, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14100
#
#
# Evaluation:
# 2016-03-11T16:28:01.357989: step 14200, loss 0.34675, acc 0.877417
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14200
#
#
# Evaluation:
# 2016-03-11T16:28:07.188428: step 14300, loss 0.345696, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14300
#
#
# Evaluation:
# 2016-03-11T16:28:13.173125: step 14400, loss 0.349881, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14400
#
#
# Evaluation:
# 2016-03-11T16:28:19.364088: step 14500, loss 0.347191, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14500
#
#
# Evaluation:
# 2016-03-11T16:28:25.272963: step 14600, loss 0.346333, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14600
#
#
# Evaluation:
# 2016-03-11T16:28:31.396111: step 14700, loss 0.348173, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14700
#
#
# Evaluation:
# 2016-03-11T16:28:37.402034: step 14800, loss 0.346686, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14800
#
#
# Evaluation:
# 2016-03-11T16:28:43.559465: step 14900, loss 0.347814, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-14900
#
#
# Evaluation:
# 2016-03-11T16:28:49.576017: step 15000, loss 0.346519, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15000
#
#
# Evaluation:
# 2016-03-11T16:28:55.673538: step 15100, loss 0.346457, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15100
#
#
# Evaluation:
# 2016-03-11T16:29:01.567100: step 15200, loss 0.349005, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15200
#
#
# Evaluation:
# 2016-03-11T16:29:07.417063: step 15300, loss 0.348068, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15300
#
#
# Evaluation:
# 2016-03-11T16:29:13.069373: step 15400, loss 0.34744, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15400
#
#
# Evaluation:
# 2016-03-11T16:29:18.679022: step 15500, loss 0.345823, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15500
#
#
# Evaluation:
# 2016-03-11T16:29:24.423701: step 15600, loss 0.346166, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15600
#
#
# Evaluation:
# 2016-03-11T16:29:29.961987: step 15700, loss 0.34516, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15700
#
#
# Evaluation:
# 2016-03-11T16:29:35.695718: step 15800, loss 0.345914, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15800
#
#
# Evaluation:
# 2016-03-11T16:29:41.252066: step 15900, loss 0.350387, acc 0.880296
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-15900
#
#
# Evaluation:
# 2016-03-11T16:29:47.030138: step 16000, loss 0.345924, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16000
#
#
# Evaluation:
# 2016-03-11T16:29:52.706211: step 16100, loss 0.350093, acc 0.880296
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16100
#
#
# Evaluation:
# 2016-03-11T16:29:58.431248: step 16200, loss 0.349401, acc 0.880296
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16200
#
#
# Evaluation:
# 2016-03-11T16:30:04.356760: step 16300, loss 0.347896, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16300
#
#
# Evaluation:
# 2016-03-11T16:30:10.431983: step 16400, loss 0.349147, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16400
#
#
# Evaluation:
# 2016-03-11T16:30:16.387996: step 16500, loss 0.349716, acc 0.880708
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16500
#
#
# Evaluation:
# 2016-03-11T16:30:22.435907: step 16600, loss 0.350001, acc 0.880708
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16600
#
#
# Evaluation:
# 2016-03-11T16:30:28.439696: step 16700, loss 0.346942, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16700
#
#
# Evaluation:
# 2016-03-11T16:30:34.562309: step 16800, loss 0.346454, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16800
#
#
# Evaluation:
# 2016-03-11T16:30:40.492906: step 16900, loss 0.351627, acc 0.880296
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-16900
#
#
# Evaluation:
# 2016-03-11T16:30:46.705353: step 17000, loss 0.348318, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17000
#
#
# Evaluation:
# 2016-03-11T16:30:52.601138: step 17100, loss 0.348289, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17100
#
#
# Evaluation:
# 2016-03-11T16:30:58.605767: step 17200, loss 0.347019, acc 0.879473
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17200
#
#
# Evaluation:
# 2016-03-11T16:31:04.231242: step 17300, loss 0.353208, acc 0.879885
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17300
#
#
# Evaluation:
# 2016-03-11T16:31:09.955459: step 17400, loss 0.350616, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17400
#
#
# Evaluation:
# 2016-03-11T16:31:15.609271: step 17500, loss 0.347285, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17500
#
#
# Evaluation:
# 2016-03-11T16:31:21.348298: step 17600, loss 0.353038, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17600
#
#
# Evaluation:
# 2016-03-11T16:31:27.002133: step 17700, loss 0.350378, acc 0.877417
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17700
#
#
# Evaluation:
# 2016-03-11T16:31:32.830302: step 17800, loss 0.351484, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17800
#
#
# Evaluation:
# 2016-03-11T16:31:38.490914: step 17900, loss 0.354411, acc 0.880296
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-17900
#
#
# Evaluation:
# 2016-03-11T16:31:44.263723: step 18000, loss 0.353887, acc 0.880708
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18000
#
#
# Evaluation:
# 2016-03-11T16:31:49.991584: step 18100, loss 0.351116, acc 0.878651
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18100
#
#
# Evaluation:
# 2016-03-11T16:31:55.651298: step 18200, loss 0.351354, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18200
#
#
# Evaluation:
# 2016-03-11T16:32:01.404970: step 18300, loss 0.349721, acc 0.878239
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18300
#
#
# Evaluation:
# 2016-03-11T16:32:07.471131: step 18400, loss 0.352134, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18400
#
#
# Evaluation:
# 2016-03-11T16:32:13.573343: step 18500, loss 0.349782, acc 0.877828
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18500
#
#
# Evaluation:
# 2016-03-11T16:32:19.610912: step 18600, loss 0.35421, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18600
#
#
# Evaluation:
# 2016-03-11T16:32:25.798206: step 18700, loss 0.35095, acc 0.877005
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18700
#
#
# Evaluation:
# 2016-03-11T16:32:31.804647: step 18800, loss 0.355066, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18800
#
#
# Evaluation:
# 2016-03-11T16:32:38.000699: step 18900, loss 0.353791, acc 0.879473
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-18900
#
#
# Evaluation:
# 2016-03-11T16:32:43.881005: step 19000, loss 0.355418, acc 0.879062
#
# Saved model checkpoint to /notebooks/AdHClassification/Expiriment #1.3 - Non-Candidate Tweets Included/runs/1457712890/checkpoints/model-19000
#
#
# Final Evaluations:
# 2016-03-11T16:32:44.637150: step 19000, loss 0.355418, acc 0.879062

# %%
    accuracies = []
    
    tp = 0
    fp = 0
    tn = 0
    fn = 0
    
    print_ct = 0
    
    for y, x in zip(y_dev, x_dev):
        a= dev_step([x], [y])
        expected = "example" if y[0] == 0 and y[1] == 1  else "nonexample"
        actual = None
        if(y[0] == 0 and y[1] == 1):
            # correct label is example
            if(a == 1.0):
                actual = "example"
            else:
                actual = "nonexample"
        elif(y[0] == 1 and y[1] == 0):
            if(a == 1.0):
                actual = "nonexample"
            else:
                actual = "example"
         

            
        if(expected == "example" and actual == "example"):
            tp += 1
            print("True Positive")
        elif(expected == "example" and actual == "nonexample"):
            fn += 1
            if(print_ct < 500):
                print_ct += 1
                sent = []
                for word in x:
                    sent.append(vocabulary_inv[word])
                print(' '.join(sent))
                
                if y[0] == 0 and y[1] == 1:
                    print("example")
                elif y[0] == 1 and y[1] == 0:
                    print("nonexample")
                else:
                    print("error")
                    
            print("False Negative")
        elif(expected == "nonexample" and actual =="exaple"):
            fp += 1
            if(print_ct < 500):
                print_ct += 1
                sent = []
                for word in x:
                    sent.append(vocabulary_inv[word])
                print(' '.join(sent))
                if y[0] == 0 and y[1] == 1:
                    print("example")
                elif y[0] == 1 and y[1] == 0:
                    print("nonexample")
                else:
                    print("error")
                    
            print("False Positive")
        elif(expected == "nonexample" and actual == "nonexample"):
            tn +=1 
            print("True Negateive")
            
        print("")
            
    print("True Positives %s" % tp)
    print("True Negatives %s" % tn)
    print("False Positives %s" % fp)
    print("False Negatives %s" % fn)
    sensitivity = (tp/(tp+float(fn)))
    print("Sensitivity: %s" % sensitivity)
    specificity = (tn/(tn+float(fp)))
    print("Specificity: %s" % specificity)
# Out:
# 2016-03-11T16:32:44.749031: step 19000, loss 0.0375059, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.751265: step 19000, loss 0.0385993, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.753841: step 19000, loss 0.0494677, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.759557: step 19000, loss 1.19307, acc 0
# <AT_NAME/> ha hes a radical fundie not respected except by other extremists i know youre just pandering <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:44.762130: step 19000, loss 0.234991, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.764328: step 19000, loss 0.0613056, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.766183: step 19000, loss 0.112291, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.768008: step 19000, loss 0.270444, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.769751: step 19000, loss 0.060672, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.771250: step 19000, loss 0.437259, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.773149: step 19000, loss 0.224933, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.774901: step 19000, loss 0.0363472, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.776682: step 19000, loss 1.40053, acc 0
# <AT_NAME/> mr holier than thou professing 2 b christian blatantly #lies 2 christians all over the country we r paying attention #oldmedia <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:44.778708: step 19000, loss 0.0554418, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.780288: step 19000, loss 0.105475, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.781946: step 19000, loss 0.0363009, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.783754: step 19000, loss 0.03852, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.785493: step 19000, loss 0.0362493, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.787223: step 19000, loss 1.95225, acc 0
# <AT_NAME/> strategy of concentrating only on nh and not iowa will backfire like it did in the case of rudolph guiliani <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:44.789285: step 19000, loss 0.0823613, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.791071: step 19000, loss 0.186137, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.792630: step 19000, loss 0.0405366, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.794500: step 19000, loss 0.0525806, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.796279: step 19000, loss 0.216672, acc 1
# True Positive
#
# 2016-03-11T16:32:44.797978: step 19000, loss 0.476839, acc 1
# True Positive
#
# 2016-03-11T16:32:44.799809: step 19000, loss 0.329953, acc 1
# True Positive
#
# 2016-03-11T16:32:44.802756: step 19000, loss 4.00104, acc 0
# the screaming you hear now from across the potomac is the #washingtoncartel in full terror that the conservative grassroots are rising up <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:44.805152: step 19000, loss 0.181144, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.807952: step 19000, loss 0.0460193, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.810707: step 19000, loss 0.0385618, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.812872: step 19000, loss 0.0427376, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.814827: step 19000, loss 1.43755, acc 0
# ted cruz does not have the right temperment to be president look at the way he totally panicked in firing his director of comm bad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:44.817191: step 19000, loss 0.186839, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.819266: step 19000, loss 0.037909, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.821557: step 19000, loss 0.0388808, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.823392: step 19000, loss 0.0363772, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.825444: step 19000, loss 0.135578, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.827556: step 19000, loss 0.0578557, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.829437: step 19000, loss 0.134059, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.831197: step 19000, loss 0.239281, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.832779: step 19000, loss 0.0720273, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.834337: step 19000, loss 0.0727499, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.836073: step 19000, loss 0.0372259, acc 1
# True Negateive
#
# 2016-03-11T16:32:44.837740: step 19000, loss 2.14902, acc 0
# <AT_NAME/> <AT_NAME/> <AT_NAME/> <AT_NAME/> <AT_NAME/> <AT_NAME/> hasnt made sense for years hes lost his damn mind its almost sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
acc 1
# True Negateive
#
# 2016-03-11T16:32:45.247944: step 19000, loss 0.997093, acc 0
# <AT_NAME/> <AT_NAME/> indict that sob cruz <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.249717: step 19000, loss 0.330283, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.252111: step 19000, loss 0.0383764, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.254264: step 19000, loss 2.95922, acc 0
#
# 2016-03-11T16:32:45.257597: step 19000, loss 0.0713051, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.259723: step 19000, loss 0.03653, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.262048: step 19000, loss 0.0538522, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.263836: step 19000, loss 0.276928, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.266140: step 19000, loss 0.0376559, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.268075: step 19000, loss 0.191697, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.271274: step 19000, loss 0.0428875, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.273284: step 19000, loss 6.92924, acc 0
# <AT_NAME/> is not ready to be president if you agree with that donate $5 to my campaign here <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.275396: step 19000, loss 0.825088, acc 0
#
# 2016-03-11T16:32:45.277292: step 19000, loss 0.0672347, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.283447: step 19000, loss 0.906167, acc 0
#
# 2016-03-11T16:32:45.285916: step 19000, loss 0.0363234, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.287779: step 19000, loss 0.0431218, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.289406: step 19000, loss 0.115457, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.291295: step 19000, loss 0.482114, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.293465: step 19000, loss 2.79933, acc 0
# <AT_NAME/> try to understand <AT_NAME/> screwed us with nafta and we know you will betray us with tpp  <AT_NAME/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.295516: step 19000, loss 0.0539119, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.297269: step 19000, loss 0.56864, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.299089: step 19000, loss 0.0369917, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.300996: step 19000, loss 0.751014, acc 0
#
# 2016-03-11T16:32:45.303040: step 19000, loss 0.0485756, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.305302: step 19000, loss 0.0394173, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.307862: step 19000, loss 0.038359, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.310038: step 19000, loss 3.9833, acc 0
# <AT_NAME/> send your worthless kids war monger <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.312024: step 19000, loss 0.0509275, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.313825: step 19000, loss 1.22281, acc 0
#
# 2016-03-11T16:32:45.315778: step 19000, loss 0.111571, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.317370: step 19000, loss 0.0370512, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.319166: step 19000, loss 1.24104, acc 0
# <AT_NAME/> <AT_NAME/> <AT_NAME/> <AT_NAME/> get real he treats people unfair and will if elected cant beat hillary <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.321859: step 19000, loss 0.0388893, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.323580: step 19000, loss 0.654792, acc 1
# True Positive
#
# 2016-03-11T16:32:45.325054: step 19000, loss 0.511582, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.327224: step 19000, loss 0.707837, acc 1
# True Positive
#
# 2016-03-11T16:32:45.336162: step 19000, loss 0.0470618, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.338567: step 19000, loss 0.0893716, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.340697: step 19000, loss 0.0538522, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.342690: step 19000, loss 0.0364858, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.344445: step 19000, loss 0.0639176, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.346474: step 19000, loss 0.0454903, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.348584: step 19000, loss 0.0362945, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.350677: step 19000, loss 0.273574, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.352537: step 19000, loss 1.40517, acc 0
#
# 2016-03-11T16:32:45.354459: step 19000, loss 0.0673224, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.356601: step 19000, loss 0.0559547, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.358644: step 19000, loss 4.25229, acc 0
# <AT_NAME/> o k here s my jokesaw hillary on the ellen showshe s sucking up to everyone except hubby bill <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.360963: step 19000, loss 0.0367218, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.363056: step 19000, loss 0.270749, acc 1
# True Negateive
#
# 2016-03-11T16:32:45
acc 1
# True Negateive
#
# 2016-03-11T16:32:45.599184: step 19000, loss 0.0362535, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.601448: step 19000, loss 0.0639176, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.603256: step 19000, loss 0.141001, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.605194: step 19000, loss 0.0527118, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.607114: step 19000, loss 0.114643, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.609079: step 19000, loss 0.0601093, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.611142: step 19000, loss 3.91817, acc 0
# <AT_NAME/> you believe the country needs a leader to mother over selfish people hillary wants to rule the world <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.613170: step 19000, loss 0.316131, acc 1
# True Positive
#
# 2016-03-11T16:32:45.614678: step 19000, loss 2.37309, acc 0
# <AT_NAME/> a whacko endorsing a whacko … great <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.616831: step 19000, loss 0.0614814, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.619145: step 19000, loss 0.198547, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.620856: step 19000, loss 0.0403893, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.622588: step 19000, loss 0.121297, acc 1
# True Positive
#
# 2016-03-11T16:32:45.624436: step 19000, loss 1.41479, acc 0
# <AT_NAME/> is throwing his twitter tantrums again what a vile man smh <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.626053: step 19000, loss 0.0466339, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.627896: step 19000, loss 0.103262, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.629811: step 19000, loss 2.18973, acc 0
# <AT_NAME/> <AT_NAME/> take it from her shes been defunct since 1988 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.632716: step 19000, loss 0.105751, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.634469: step 19000, loss 0.404419, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.636163: step 19000, loss 0.0611911, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.637818: step 19000, loss 0.0894272, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.639734: step 19000, loss 0.97515, acc 0
#
# 2016-03-11T16:32:45.641586: step 19000, loss 0.254178, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.643506: step 19000, loss 0.0402193, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.653386: step 19000, loss 0.0363071, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.655836: step 19000, loss 0.0740461, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.658016: step 19000, loss 0.0462947, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.660106: step 19000, loss 0.0400332, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.662626: step 19000, loss 0.0529617, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.664797: step 19000, loss 0.0559846, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.666936: step 19000, loss 0.0376227, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.669189: step 19000, loss 0.0379718, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.671237: step 19000, loss 0.0366124, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.673220: step 19000, loss 0.0374844, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.675462: step 19000, loss 0.036737, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.677486: step 19000, loss 0.149305, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.679320: step 19000, loss 1.47217, acc 0
# <AT_NAME/> why dont you learn what a church is and try going to one <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.681795: step 19000, loss 2.10866, acc 0
# <AT_NAME/> donald its time to quit the attacks on your competitors and start attacking hillary clinton we must defeat the democrats <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.684995: step 19000, loss 0.106783, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.687054: step 19000, loss 0.0493905, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.689008: step 19000, loss 4.30407, acc 0
# <AT_NAME/> youre not trying to jew us over are you bernie <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# False Negative
#
# 2016-03-11T16:32:45.690913: step 19000, loss 0.128032, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.692684: step 19000, loss 0.0367538, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.694310: step 19000, loss 0.0362596, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.696104: step 19000, loss 0.206122, acc 1
# True Positive
#
# 2016-03-11T16:32:45.698730: step 19000, loss 0.0561682, acc 1
# True Positive
#
# 2016-03-11T16:32:45.701172: step 19000, loss 0.040361, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.703991: step 19000, loss 0.0396975, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.706250: step 19000, loss 0.381787, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.709140: step 19000, loss 0.0539119, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.711009: step 19000, loss 0.0363542, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.712865: step 19000, loss 0.0797287, acc 1
# True Negateive
#
# 2016-03-11T16:32:45.715318: step 19000, loss 0.0400418, acc 1
# True Negateive
#
# 2016-03-11T16:32:45