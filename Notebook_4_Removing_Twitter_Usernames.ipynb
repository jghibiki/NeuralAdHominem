# %% [markdown]
# # Notebook 2: CNN
#
# ## Overview:
#
# 1. Begin by importing and getting the embeddings and word to index mappings we created in [Notebook 1: Embed Words](Notebook_1_Embed_Words.ipynb)

# %%
import cPickle as pickle
from tensorflow.models.rnn.rnn_cell import BasicLSTMCell, LSTMCell 
import itertools
from collections import Counter
import csv
import re
import numpy as np
import string

# %%
embeddings = None
mappings = None
rows = None

with open("word_embeddings.pkl", "rb") as f:
    embeddings = pickle.load(f)
with open("word_mappings.pkl", "rb") as f:
    mappings = pickle.load(f)
    

urlFinder = re.compile('\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*')
atNameFinder = re.compile(r'@([A-Za-z0-9_]+)')
atNameCounter = 0

exclude_punc = set([
        "!",
        "?",
        ".",
        ",",
        ":",
        ";",
        "'",
        "\"",
        "“",
        "’",
        "-"
])

sentences = []
labels = []
x = []
y = []

with open('data.csv', 'rb') as f:
    reader = csv.reader(f, delimiter=',')   
    
    for row in reader:
        words = []
        
        for word in row[1] \
            .strip() \
            .replace("&amp;", "") \
            .replace("&gt;","") \
            .replace("&lt;", "") \
            .lower().split():
            
            if urlFinder.match(word):
                words.append("<URL/>")
            elif atNameFinder.search(word):
                words.append("<AT_NAME_%s/>" % atNameCounter)
                atNameCounter +=1
            else:
                word = ''.join(ch for ch in word if ch not in exclude_punc)
                words.append(word)
        sentences.append(words)
        labels.append(([0, 1] if row[0] == "example" else [1, 0]))


sequence_length = max(len(i) for i in sentences)
padded_sentences = []
for i in range(len(sentences)):
    sentence = sentences[i]
    num_padding = sequence_length - len(sentence)
    new_sentence = sentence + ["<PAD/>"] * num_padding
    padded_sentences.append(new_sentence)
    
 
word_counts = Counter(itertools.chain(*padded_sentences))

# Mapping from index to word
vocabulary_inv = [x[0] for x in word_counts.most_common()]
# Mapping from word to index
vocabulary = {x: i for i, x in enumerate(vocabulary_inv)}

x = np.array([[vocabulary[word] for word in sentence] for sentence in padded_sentences])
y = np.array(labels)

# %%
import tensorflow as tf
import numpy as np


class TextCNN(object):
    """
    A CNN for text classification.
    Uses an embedding layer, followed by a convolutional, max-pooling and softmax layer.
    """
    def __init__(
      self, sequence_length, num_classes, vocab_size,
      embedding_size, filter_sizes, num_filters, l2_reg_lambda=0.0):

        # Placeholders for input, output and dropout
        self.input_x = tf.placeholder(tf.int32, [None, sequence_length], name="input_x")
        self.input_y = tf.placeholder(tf.float32, [None, num_classes], name="input_y")
        self.dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")

        # Keeping track of l2 regularization loss (optional)
        l2_loss = tf.constant(0.0)

        # Embedding layer
        with tf.device('/cpu:0'), tf.name_scope("embedding"):
            W = tf.Variable(
                tf.random_uniform([vocab_size, embedding_size], -1.0, 1.0),
                name="W")
            self.embedded_chars = tf.nn.embedding_lookup(W, self.input_x)
            self.embedded_chars_expanded = tf.expand_dims(self.embedded_chars, -1)

        # Create a convolution + maxpool layer for each filter size
        pooled_outputs = []
        for i, filter_size in enumerate(filter_sizes):
            with tf.name_scope("conv-maxpool-%s" % filter_size):
                # Convolution Layer
                filter_shape = [filter_size, embedding_size, 1, num_filters]
                W = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W")
                b = tf.Variable(tf.constant(0.1, shape=[num_filters]), name="b")
                conv = tf.nn.conv2d(
                    self.embedded_chars_expanded,
                    W,
                    strides=[1, 1, 1, 1],
                    padding="VALID",
                    name="conv")
                # Apply nonlinearity
                h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                # Maxpooling over the outputs
                pooled = tf.nn.max_pool(
                    h,
                    ksize=[1, sequence_length - filter_size + 1, 1, 1],
                    strides=[1, 1, 1, 1],
                    padding='VALID',
                    name="pool")
                pooled_outputs.append(pooled)

        # Combine all the pooled features
        num_filters_total = num_filters * len(filter_sizes)
        self.h_pool = tf.concat(3, pooled_outputs)
        self.h_pool_flat = tf.reshape(self.h_pool, [-1, num_filters_total])

        # Add dropout
        with tf.name_scope("dropout"):
            self.h_drop = tf.nn.dropout(self.h_pool_flat, self.dropout_keep_prob)

        # Final (unnormalized) scores and predictions
        with tf.name_scope("output"):
            W = tf.Variable(tf.truncated_normal([num_filters_total, num_classes], stddev=0.1), name="W")
            b = tf.Variable(tf.constant(0.1, shape=[num_classes]), name="b")
            l2_loss += tf.nn.l2_loss(W)
            l2_loss += tf.nn.l2_loss(b)
            self.scores = tf.nn.xw_plus_b(self.h_drop, W, b, name="scores")
            self.predictions = tf.argmax(self.scores, 1, name="predictions")

        # CalculateMean cross-entropy loss
        with tf.name_scope("loss"):
            losses = tf.nn.softmax_cross_entropy_with_logits(self.scores, self.input_y)
            self.loss = tf.reduce_mean(losses) + l2_reg_lambda * l2_loss

        # Accuracy
        with tf.name_scope("accuracy"):
            correct_predictions = tf.equal(self.predictions, tf.argmax(self.input_y, 1))
            self.accuracy = tf.reduce_mean(tf.cast(correct_predictions, "float"), name="accuracy")

# %%
def batch_iter(data, batch_size, num_epochs):
    """
    Generates a batch iterator for a dataset.
    """
    data = np.array(data)
    data_size = len(data)
    num_batches_per_epoch = int(len(data)/batch_size) + 1
    for epoch in range(num_epochs):
        # Shuffle the data at each epoch
        shuffle_indices = np.random.permutation(np.arange(data_size))
        shuffled_data = data[shuffle_indices]
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, data_size)
            yield shuffled_data[start_index:end_index]

# %%
import tensorflow as tf
import numpy as np
import os
import time
import datetime

# Parameters
# ==================================================

# Model Hyperparameters
embedding_dim = 128  #Dimensionality of character embedding (default: 128)
filter_sizes =  "3,4,5" #"Comma-separated filter sizes (default: '3,4,5')")
num_filters = 128  #"Number of filters per filter size (default: 128)")
dropout_keep_prob = 0.5 #"Dropout keep probability (default: 0.5)")
l2_reg_lambda = 0.0 #"L2 regularizaion lambda (default: 0.0)")

# Training parameters
batch_size = 64 # "Batch Size (default: 64)")
num_epochs = 200 #"Number of training epochs (default: 200)")
evaluate_every = 500  #"Evaluate model on dev set after this many steps (default: 100)")
checkpoint_every = 10000 # "Save model after this many steps (default: 100)")
# Misc Parameters
allow_soft_placement = True # "Allow device soft device placement")
log_device_placement = False  #"Log placement of ops on devices")
display_train_steps = False # toggles output of training step results



# Data Preparatopn
# ==================================================

# Load data
print("Loading data...")
# Randomly shuffle data
np.random.seed(10)
shuffle_indices = np.random.permutation(np.arange(len(y)))
x_shuffled = x[shuffle_indices]
y_shuffled = y[shuffle_indices]
# Split train/test set
# TODO: This is very crude, should use cross-validation
x_train, x_dev = x_shuffled[:len(x_shuffled)-1], x_shuffled[-len(x_shuffled)-1:]
y_train, y_dev = y_shuffled[:len(y_shuffled)-1], y_shuffled[-len(y_shuffled)-1:]
print("Vocabulary Size: {:d}".format(len(vocabulary)))
print("Train/Dev split: {:d}/{:d}".format(len(y_train), len(y_dev)))
print("Train Pos/Dev Pos Split {:d}/{:d}"
      .format(
        len(
            [y for y in y_train if y[0] == 0 and y[1] == 1]
        ), len(
            [y for y in y_dev if y[0] == 0 and y[1] == 1]
        )))
print("Train Neg/Dev Neg Split {:d}/{:d}"
      .format(
        len(
            [y for y in y_train if y[0] == 1 and y[1] == 0]
        ), len(
            [y for y in y_dev if y[0] == 1 and y[1] == 0]
        )))


# Training
# ==================================================

with tf.Graph().as_default():
    session_conf = tf.ConfigProto(
      allow_soft_placement=allow_soft_placement,
      log_device_placement=log_device_placement)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        cnn = TextCNN(
            sequence_length=x_train.shape[1],
            num_classes=2,
            vocab_size=len(vocabulary),
            embedding_size=embedding_dim,
            filter_sizes=map(int, filter_sizes.split(",")),
            num_filters=num_filters,
            l2_reg_lambda=l2_reg_lambda)

        # Define Training procedure
        global_step = tf.Variable(0, name="global_step", trainable=False)
        optimizer = tf.train.AdamOptimizer(1e-4)
        grads_and_vars = optimizer.compute_gradients(cnn.loss)
        train_op = optimizer.apply_gradients(grads_and_vars, global_step=global_step)

        # Keep track of gradient values and sparsity (optional)
        grad_summaries = []
        for g, v in grads_and_vars:
            if g is not None:
                grad_hist_summary = tf.histogram_summary("{}/grad/hist".format(v.name), g)
                sparsity_summary = tf.scalar_summary("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                grad_summaries.append(grad_hist_summary)
                grad_summaries.append(sparsity_summary)
        grad_summaries_merged = tf.merge_summary(grad_summaries)

        # Output directory for models and summaries
        timestamp = str(int(time.time()))
        out_dir = os.path.abspath(os.path.join(os.path.curdir, "runs", timestamp))
        print("Writing to {}\n".format(out_dir))

        # Summaries for loss and accuracy
        loss_summary = tf.scalar_summary("loss", cnn.loss)
        acc_summary = tf.scalar_summary("accuracy", cnn.accuracy)

        # Train Summaries
        train_summary_op = tf.merge_summary([loss_summary, acc_summary, grad_summaries_merged])
        train_summary_dir = os.path.join(out_dir, "summaries", "train")
        train_summary_writer = tf.train.SummaryWriter(train_summary_dir, sess.graph_def)

        # Dev summaries
        dev_summary_op = tf.merge_summary([loss_summary, acc_summary])
        dev_summary_dir = os.path.join(out_dir, "summaries", "dev")
        dev_summary_writer = tf.train.SummaryWriter(dev_summary_dir, sess.graph_def)

        # Checkpoint directory. Tensorflow assumes this directory already exists so we need to create it
        checkpoint_dir = os.path.abspath(os.path.join(out_dir, "checkpoints"))
        checkpoint_prefix = os.path.join(checkpoint_dir, "model")
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        saver = tf.train.Saver(tf.all_variables())

        # Initialize all variables
        sess.run(tf.initialize_all_variables())

        def train_step(x_batch, y_batch):
            """
            A single training step
            """
            feed_dict = {
              cnn.input_x: x_batch,
              cnn.input_y: y_batch,
              cnn.dropout_keep_prob: dropout_keep_prob
            }
            _, step, summaries, loss, accuracy = sess.run(
                [train_op, global_step, train_summary_op, cnn.loss, cnn.accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            if(display_train_steps):
                print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
            train_summary_writer.add_summary(summaries, step)

        def dev_step(x_batch, y_batch, writer=None):
            """
            Evaluates model on a dev set
            """
            feed_dict = {
              cnn.input_x: x_batch,
              cnn.input_y: y_batch,
              cnn.dropout_keep_prob: 1.0
            }
            step, summaries, loss, accuracy = sess.run(
                [global_step, dev_summary_op, cnn.loss, cnn.accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            print("{}: step {}, loss {:g}, acc {:g}".format(time_str, step, loss, accuracy))
            if writer:
                writer.add_summary(summaries, step)

        # Generate batches
        batches = batch_iter(
            zip(x_train, y_train), batch_size, num_epochs)
        # Training loop. For each batch...
        for batch in batches:
            x_batch, y_batch = zip(*batch)
            train_step(x_batch, y_batch)
            current_step = tf.train.global_step(sess, global_step)
            if current_step % evaluate_every == 0:
                print("\nEvaluation:")
                dev_step(x_dev, y_dev, writer=dev_summary_writer)
                print("")
            if current_step % checkpoint_every == 0:
                path = saver.save(sess, checkpoint_prefix, global_step=current_step)
                print("Saved model checkpoint to {}\n".format(path))
        
        print("\nFinal Evaluations:")
        dev_step(x_dev, y_dev, writer=dev_summary_writer)
  
        
        print("")
# Out:
# Loading data...
# Vocabulary Size: 6197
# Train/Dev split: 2983/2984
# Train Pos/Dev Pos Split 211/211
# Train Neg/Dev Neg Split 2772/2773
# Writing to /notebooks/AdHClassification/Expiriment #1.2 - Candidate Tweets More Data/runs/1457145639
#
#
# Evaluation:
# 2016-03-05T02:42:23.106407: step 500, loss 0.348911, acc 0.929625
#
#
# Evaluation:
# 2016-03-05T02:44:04.895155: step 1000, loss 0.175221, acc 0.938673
#
#
# Evaluation:
# 2016-03-05T02:45:47.576486: step 1500, loss 0.0796707, acc 0.963807
#
#
# Evaluation:
# 2016-03-05T02:47:31.484446: step 2000, loss 0.034663, acc 0.984584
#
#
# Evaluation:
# 2016-03-05T02:49:13.786093: step 2500, loss 0.013336, acc 0.995308
#
#
# Evaluation:
# 2016-03-05T02:50:55.187888: step 3000, loss 0.00725353, acc 0.999665
#
#
# Evaluation:
# 2016-03-05T02:52:36.540554: step 3500, loss 0.00349926, acc 0.999665
#
#
# Evaluation:
# 2016-03-05T02:54:19.314941: step 4000, loss 0.00226239, acc 0.999665
#
#
# Evaluation:
# 2016-03-05T02:56:01.023344: step 4500, loss 0.000974497, acc 1
#
#
# Evaluation:
# 2016-03-05T02:57:41.831296: step 5000, loss 0.000621236, acc 1
#
#
# Evaluation:
# 2016-03-05T02:59:22.582369: step 5500, loss 0.000422994, acc 1
#
#
# Evaluation:
# 2016-03-05T03:01:05.036335: step 6000, loss 0.000425221, acc 1
#
#
# Evaluation:
# 2016-03-05T03:02:47.090153: step 6500, loss 0.000202572, acc 1
#
#
# Evaluation:
# 2016-03-05T03:04:27.797626: step 7000, loss 0.00018941, acc 1
#
#
# Evaluation:
# 2016-03-05T03:06:08.564137: step 7500, loss 9.95708e-05, acc 1
#
#
# Evaluation:
# 2016-03-05T03:07:49.804353: step 8000, loss 8.1904e-05, acc 1
#
#
# Evaluation:
# 2016-03-05T03:09:32.058408: step 8500, loss 7.78502e-05, acc 1
#
#
# Evaluation:
# 2016-03-05T03:11:13.450116: step 9000, loss 6.07441e-05, acc 1
#
#
# Final Evaluations:
# 2016-03-05T03:12:35.301049: step 9400, loss 4.89333e-05, acc 1

# %%
        pos_x_dev = []
        pos_y_dev = []

        neg_x_dev = []
        neg_y_dev = []

        for y, x in zip(y_dev, x_dev):
            if(y[0] == 0 and y[1] == 1):
                pos_x_dev.append(x)
                pos_y_dev.append(y)
            else:
                neg_x_dev.append(x)
                neg_y_dev.append(y)
        even_x_dev = np.array(pos_x_dev + neg_x_dev[:len(pos_x_dev)])
        even_y_dev = np.array(pos_y_dev + neg_y_dev[:len(pos_y_dev)])
        print(len(even_y_dev), len(even_x_dev))

        print("Balanced Evaluation:")
        dev_step(even_x_dev, even_y_dev, writer=dev_summary_writer)
# Out:
# (422, 422)
# Balanced Evaluation:
# 2016-03-05T03:12:35.556935: step 9400, loss 0.000209586, acc 1

# %%
    for y, x in zip(even_y_dev, even_x_dev):
        sent = []
        for word in x:
            sent.append(vocabulary_inv[word])
        print(' '.join(sent))
        print("example" if y[0] == 0 and y[1] == 1 else "nonexample")
        dev_step([x], [y], writer=dev_summary_writer)
        print("")
        print("")
# Out:
# dopey mort zuckerman owner of the worthless <AT_NAME_477/> has a major inferiority complex paper will close soon <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.570721: step 9400, loss 0.00047577, acc 1
#
#
# <AT_NAME_207/> looks more like a gym rat than a us senator how the hell did he ever get elected <AT_NAME_208/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.574687: step 9400, loss 5.09011e-05, acc 1
#
#
# jebs tested transparent to get <AT_NAME_132/> info you need a subpoena #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.578271: step 9400, loss 0.000755859, acc 1
#
#
# <AT_NAME_419/> jeb bush was as ineffectual as ever as always <AT_NAME_420/> calls it right trump held them off #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.581626: step 9400, loss 0.000154841, acc 1
#
#
# three times <AT_NAME_145/> refused to answer the question #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.584927: step 9400, loss 0.000897005, acc 1
#
#
# pathetic attempt by <AT_NAME_13/> to try and build up ratings for the #gopdebate without me theyd have no ratings <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.588078: step 9400, loss 0.00164278, acc 1
#
#
# its not tough to take an elderly womans home <AT_NAME_391/> #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.591406: step 9400, loss 0.000419052, acc 1
#
#
# ted cruz is lying again polls are showing that i do beat hillary clinton head to head check out <URL/> poll snd q poll <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.594900: step 9400, loss 0.000143041, acc 1
#
#
# response to the lies of senator cruz <URL/> #trump2016 #votetrumpsc <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.599259: step 9400, loss 0.000619815, acc 1
#
#
# flashback hillary clinton unaccompanied minors should be sent back <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.607250: step 9400, loss 0.000106448, acc 1
#
#
# <AT_NAME_445/> time to come up with a new script #notready <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.613819: step 9400, loss 0.000558935, acc 1
#
#
# mitt romney who was one of the dumbest and worst candidates in the history of republican politics is now pushing me on tax returns dope <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.621100: step 9400, loss 0.0016216, acc 1
#
#
# why would texans vote for liar ted cruz when he was born in canada lived there for 4 yearsand remained a canadian citizen until recently <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.629855: step 9400, loss 1.69276e-05, acc 1
#
#
# take a look at jeb’s record as a conservative reformer vs <AT_NAME_389/> record as a donothing senator #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.635876: step 9400, loss 0.000113838, acc 1
#
#
# great night at the #gopdebate i took on <AT_NAME_637/> to show he is unfit to serve as commanderinchief watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.640469: step 9400, loss 0.000227902, acc 1
#
#
# clinton electability faces scrutiny <URL/> via mark gersh <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.644925: step 9400, loss 0.000367336, acc 1
#
#
# track two from the album #scripted in essence <URL/> cc <AT_NAME_327/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.658200: step 9400, loss 0.00046028, acc 1
#
#
# <AT_NAME_57/> <AT_NAME_58/> <AT_NAME_59/> <AT_NAME_60/> is fighting corruption big donors took over cruz no to donors <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.662753: step 9400, loss 8.07014e-05, acc 1
#
#
# <AT_NAME_161/> cut and ran on his policy stances when his position became politically unpopular <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.666629: step 9400, loss 4.76826e-05, acc 1
#
#
# the iranians know a mark when they see one want more concessions before obama leaves office <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.670595: step 9400, loss 4.76826e-05, acc 1
#
#
# dont let #duckingdonald skip the debate get your #maketrumpdebateagain hat today  <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.675199: step 9400, loss 0.000321337, acc 1
#
#
# remember that marco rubio is very weak on illegal immigration south carolina needs strength as illegals and syrians pour in dont allow it <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.683155: step 9400, loss 0.000211574, acc 1
#
#
# <AT_NAME_510/> <AT_NAME_511/> <AT_NAME_512/> <AT_NAME_513/> ted cruz is the definition of sleaze just ask <AT_NAME_514/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.692648: step 9400, loss 0.000108951, acc 1
#
#
# washington is broken and both parties are to blame <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.697847: step 9400, loss 0.00304961, acc 1
#
#
# everybody is laughing at jeb bushspent $100 million and is at bottom of pack a pathetic figure <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.703487: step 9400, loss 0.000171647, acc 1
#
#
# <AT_NAME_653/> is trafficking 9/11 conspiracy theories i’m offering detailed plans to defeat isis we need a serious commanderinchief <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.707836: step 9400, loss 0.000114434, acc 1
#
#
# i hear that <AT_NAME_115/> $$ man robert mercer a good man is very angry because cruz lied to him about liquidating his (ted’s) holdings <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.711485: step 9400, loss 1.93117e-05, acc 1
#
#
# just watched the very incompetent mitt romney campaign strategist stuart stevens now i know why mitt lost so badly stevens is a clown <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.715431: step 9400, loss 4.72058e-05, acc 1
#
#
# watching biased charles <AT_NAME_121/> a <AT_NAME_122/> flunky who didnt know that i won every debate in particular the last one check polls <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.722427: step 9400, loss 0.000449795, acc 1
#
#
# <AT_NAME_87/> <AT_NAME_88/> why do they have so many debates this year also why is cruz still allowed to run hes not eligible <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.728172: step 9400, loss 5.01859e-05, acc 1
#
#
# while <AT_NAME_599/> was building a reality tv show my brother was building a security apparatus to keep us safe #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.735310: step 9400, loss 4.81594e-05, acc 1
#
#
# jeb is a hypocrite used massive private eminent domain  just another clueless politician <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.738903: step 9400, loss 7.6887e-05, acc 1
#
#
# hey <AT_NAME_617/> see how i beat your boy ted in your own blaze poll your endorsement means nothing #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.742395: step 9400, loss 0.000213243, acc 1
#
#
# <AT_NAME_723/> who had zero in his presidential run before dropping out in disgrace saying the most horrible things about me on <AT_NAME_724/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.745912: step 9400, loss 0.00026306, acc 1
#
#
# taking an elderly womans home to build a parking lot for a failed casino isnt the proper use of eminent domain <AT_NAME_607/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.749418: step 9400, loss 8.6423e-05, acc 1
#
#
# make sure you get on the trump line and are not mislead by the cruz people they are bad be careful <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.753104: step 9400, loss 0.00027903, acc 1
#
#
# rt if you agree donald trump should release his tax returns <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.756452: step 9400, loss 7.89134e-05, acc 1
#
#
# <AT_NAME_373/> <AT_NAME_374/> ia caucus hasnt picked nominee in 16 years cruz dirty tricks stole it trump way ahead in primary states <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.760262: step 9400, loss 0.000161396, acc 1
#
#
# track three of <AT_NAME_330/> album #scripted votes dont mean a thing <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.763856: step 9400, loss 0.000140895, acc 1
#
#
# bonus track a ballad of love loss and amnesty from <AT_NAME_336/> album #scripted <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.767432: step 9400, loss 0.00027617, acc 1
#
#
# we are getting reports from many voters that the cruz people are back to doing very sleazy and dishonest pushpolls on me we are watching <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.770882: step 9400, loss 0.000178917, acc 1
#
#
# remembering back when <AT_NAME_7/> wasnt attacking conservatives <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.774541: step 9400, loss 0.000234934, acc 1
#
#
# <AT_NAME_1009/> marco cruz and ted rubio (easy to get the two politicians confused) looked like desperate panicked dc insiders tonight <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.777781: step 9400, loss 0.000134936, acc 1
#
#
# <AT_NAME_337/> i wont cut social security as always ill defend it ill expand it enough false innuendos <URL/> h <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.782100: step 9400, loss 5.80532e-05, acc 1
#
#
# word is that little morty zuckerman’s <AT_NAME_554/> loses more than $50 million per yearcan that be possible <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.788670: step 9400, loss 4.01727e-05, acc 1
#
#
# president obama’s foreign policy has consistently alienated and abandoned our friends while showing our enemies appeasement #goptownhall <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.796402: step 9400, loss 0.000641736, acc 1
#
#
# the new email release is a disaster for hillary clinton at a minimum how can someone with such bad judgement be our next president <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.801794: step 9400, loss 0.000235172, acc 1
#
#
# both donald trump hillary want to be neutral between israel and the palestinians if im elected well stand unapologetically with israel <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.805355: step 9400, loss 0.000463378, acc 1
#
#
# how can ted cruz be an evangelical christian when he lies so much and is so dishonest <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.809199: step 9400, loss 2.20535e-05, acc 1
#
#
# last time lightweight <AT_NAME_535/> tried to knock off <AT_NAME_536/> he made a total fool of himself if he doesnt do better this time he is out <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.813242: step 9400, loss 7.11654e-05, acc 1
#
#
# enough with playground pranks and disparaging americans <AT_NAME_299/> we need a real leader <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.817808: step 9400, loss 0.000884499, acc 1
#
#
# were never going to get anything done in washington if our leaders cut and run <AT_NAME_139/> #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.822875: step 9400, loss 0.000233385, acc 1
#
#
# when mitt romney asked me for my endorsement last time around he was so awkward and goofy that we all should have known he could not win <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.828444: step 9400, loss 0.000150669, acc 1
#
#
# going to tonights #gopdebate look for this #duckingdonald <AT_NAME_114/> filter  <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.852138: step 9400, loss 0.000176414, acc 1
#
#
# <AT_NAME_964/> <AT_NAME_965/> romney should have been a tough guy with obama he cowered and lost badly hes not relevant <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.859034: step 9400, loss 0.000547855, acc 1
#
#
# like the worthless <AT_NAME_479/> looks like <AT_NAME_480/> will be going out of business bad reporting no money no cred <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.864437: step 9400, loss 0.000241727, acc 1
#
#
# jeb bush spent more than $40000000 in new hampshire to come in 4 or 5 i spent $3000000 to come in 1st big difference in capability <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.871819: step 9400, loss 0.000283797, acc 1
#
#
# why would the people of florida vote for marco rubio when he defrauded them by agreeing to represent them as their senator and then quit <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.878935: step 9400, loss 0.000552263, acc 1
#
#
# lightweight marco rubio was working hard last night the problem is he is a choker and once a choker always a chocker mr meltdown <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.886607: step 9400, loss 2.14574e-05, acc 1
#
#
# as the media discovers more facts surrounding ted cruzs campaign resorting to dirty tricks even they are appalled <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.893272: step 9400, loss 2.41992e-05, acc 1
#
#
# <AT_NAME_906/> showing class grace calls me a soft weak little baby hope he doesnt try to eat me <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.898331: step 9400, loss 1.78812e-05, acc 1
#
#
# the failing <AT_NAME_523/> destroyed by little morty zuckerman is preparing to close and save face by going online its dead <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.903890: step 9400, loss 0.000162469, acc 1
#
#
# after hearing the news that they would not be able to extort $1m from me they went hostile w/ a series of incorrect illinformed ads <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.908005: step 9400, loss 0.000483396, acc 1
#
#
# <AT_NAME_5/> do you know who else is scared of tough qs from fox <AT_NAME_6/> barack obama enough whining <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.911769: step 9400, loss 5.23315e-05, acc 1
#
#
# how can <AT_NAME_616/> beat hillary clinton if he cant beat anyone else on the #gopdebate stage with $150m i am the only one who can <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.915399: step 9400, loss 0.000272594, acc 1
#
#
# lightweight <AT_NAME_614/> said tonight he didnt know his family used private eminent domain in texas lie #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.919574: step 9400, loss 5.555e-05, acc 1
#
#
# <AT_NAME_130/> put americas secrets at risk for her convenience <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.923155: step 9400, loss 3.00403e-05, acc 1
#
#
# all polls have me winning debate big drudge time etc dopey charles krauthammer still nasty he has zero cred totally dishonest <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.927113: step 9400, loss 1.7166e-05, acc 1
#
#
# yet more details about how <AT_NAME_251/> put her political security ahead of national security <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.931054: step 9400, loss 0.000489115, acc 1
#
#
# really dumb <AT_NAME_341/> begged my people for a job turned her down twice and she went hostile major loser zero credibility <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.934322: step 9400, loss 0.000139465, acc 1
#
#
# the reason that ted cruz lost the evangelicals in sc is because he is a world class liar and evangelicals do not like liars <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.943477: step 9400, loss 1.47818e-05, acc 1
#
#
# it’s official the fbi confirms it is investigating hillary clinton’s private server <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.947057: step 9400, loss 0.00132592, acc 1
#
#
# its been 17 days 16 hours and 32 minutes since <AT_NAME_865/> said she would look into releasing her paid speeches to wall street <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.951170: step 9400, loss 4.48217e-05, acc 1
#
#
# <AT_NAME_815/> mrtrumpboth cruz and rubio are ineligible to be potus its a slam dunk case check it <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.956821: step 9400, loss 4.55369e-05, acc 1
#
#
# when little morty zuckerman closes his failing <AT_NAME_553/> will i at least be given some credit will happen soon <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.960956: step 9400, loss 0.000215865, acc 1
#
#
# <AT_NAME_131/> put americas secrets at risk for her convenience #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.964339: step 9400, loss 1.7166e-05, acc 1
#
#
# falsely accusing someone of lying is itself a lie and its something <AT_NAME_995/> does daily #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.967955: step 9400, loss 0.000164257, acc 1
#
#
# the failing <AT_NAME_841/> wall street journal should fire both its pollster and its editorial board seldom has a paper been so wrongtotally biased <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.971344: step 9400, loss 3.81462e-05, acc 1
#
#
# ted cruz does not have the right temperment to be president look at the way he totally panicked in firing his director of comm bad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.975254: step 9400, loss 4.24376e-05, acc 1
#
#
# nasty ted cruz is at it again same dirty tricks he used w/ <AT_NAME_592/> saying i may not be on ballot i hold liberal positions lies <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.981080: step 9400, loss 5.37619e-05, acc 1
#
#
# <AT_NAME_1010/> <AT_NAME_1011/> trump won the debate disgusting rubio said peed  is he still in junior high school <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.988250: step 9400, loss 7.05694e-05, acc 1
#
#
# the screaming you hear now from across the potomac is the #washingtoncartel in full terror that the conservative grassroots are rising up <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.993166: step 9400, loss 0.000103588, acc 1
#
#
# <AT_NAME_364/> <AT_NAME_365/> <AT_NAME_366/> <AT_NAME_367/> how come rubiocruz are going to turn america around but did nothing in the senate for usa <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:35.998972: step 9400, loss 0.0003093, acc 1
#
#
# if <AT_NAME_38/> can’t handle the <AT_NAME_39/> debate what else will he not be able to handle <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.003925: step 9400, loss 0.000105495, acc 1
#
#
# <AT_NAME_954/> <AT_NAME_955/> a vote for <AT_NAME_956/> or <AT_NAME_957/> is a vote for corruption special interests and lobbyists trump for potus <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.009303: step 9400, loss 0.000308824, acc 1
#
#
# track one of the album #scripted is i got 3 questions but only 1 answer cc <AT_NAME_319/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.013850: step 9400, loss 9.09526e-05, acc 1
#
#
# jeb bush has zero communication skills so he spent a fortune of special interest money on a super bowl ad he is a weak candidate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.024103: step 9400, loss 5.93645e-05, acc 1
#
#
# wow was ted cruz disloyal to his very capable director of communication he used him as a scape goatfired like a dog ted panicked <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.029667: step 9400, loss 6.19886e-06, acc 1
#
#
# <AT_NAME_720/> <AT_NAME_721/> <AT_NAME_722/> scary how smoothly cruz looks into the camera and lies about trump cant be #potus #trump2016 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.036196: step 9400, loss 1.89541e-05, acc 1
#
#
# im sick and tired of trump attacking my family this isnt about my family or his family its about your family #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.041993: step 9400, loss 0.000352321, acc 1
#
#
# during last night’s #gopdebate i called out <AT_NAME_641/> he is not a true conservative watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.048291: step 9400, loss 0.000137439, acc 1
#
#
# <AT_NAME_813/> <AT_NAME_814/> is really starting to campaign hard for marcorubio #fairandbalancedmyass he is weak on illegal immigration <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.054738: step 9400, loss 0.000100846, acc 1
#
#
# weak jeb getting thrown out by management during speech do you think he will be this tough on putin others <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.060692: step 9400, loss 0.000127665, acc 1
#
#
# this election is about defeating hillary clinton and about saving what makes america unique <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.065280: step 9400, loss 0.000443599, acc 1
#
#
# you know whats weak <AT_NAME_605/> disparaging women hispanics american heroes like john mccain #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.071682: step 9400, loss 4.69674e-05, acc 1
#
#
# lightweight <AT_NAME_528/> is spending a fortune of special interest against me in sc false advertising desperate and sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.078365: step 9400, loss 8.57078e-05, acc 1
#
#
# lying ted cruz and leightweight chocker marco rubio teamed up last night in a last ditch effort to stop our great movement they failed <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.082109: step 9400, loss 1.78812e-05, acc 1
#
#
# do you think <AT_NAME_1/> knows about <AT_NAME_2/> dealings actually i doubt it <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.085573: step 9400, loss 0.000459327, acc 1
#
#
# ted cruz is a cheater he holds the bible high and then lies and misrepresents the facts <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.089423: step 9400, loss 8.12974e-05, acc 1
#
#
# wow jeb bush whose campaign is a total disaster had to bring in mommy to take a slap at me not nice <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.092845: step 9400, loss 0.000257697, acc 1
#
#
# while <AT_NAME_609/> was building a reality tv show my brother was keeping us safe #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.096790: step 9400, loss 2.57489e-05, acc 1
#
#
# <AT_NAME_853/> <AT_NAME_854/> <AT_NAME_855/> floridians are upset because rubio did not do what he promised once he was elected vote trump <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.100496: step 9400, loss 5.14971e-05, acc 1
#
#
# why does <AT_NAME_717/> devote so much time on her shows to me almost always negative without me her ratings would tank get a life megyn <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.103945: step 9400, loss 0.000124328, acc 1
#
#
# disparaging women hispanics the disabled isnt a sign of strength its a sign of weakness <AT_NAME_144/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.107979: step 9400, loss 0.00013875, acc 1
#
#
# leightweight chocker marco rubio looks like a little boy on stage not presidential material <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.112995: step 9400, loss 1.84773e-05, acc 1
#
#
# a big fat hit job on <AT_NAME_880/> tonight a total waste of time to watch boring and biased <AT_NAME_881/> said i would never run a dope <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.116523: step 9400, loss 0.000174984, acc 1
#
#
# even though every poll time drudge etc has me winning the debate by a lot <AT_NAME_620/> only puts negative people on biased  a total joke <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.120650: step 9400, loss 4.88746e-05, acc 1
#
#
# ted cruz lifts the bible high into the air and then lies like a dogover and over again the evangelicals in sc figured him out said no <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.131447: step 9400, loss 0.00010323, acc 1
#
#
# obama clinton should stop being dishonest admit their incrementalist isis strategy is failing <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.139553: step 9400, loss 7.96286e-05, acc 1
#
#
# appalling for <AT_NAME_753/> to legitimize the castro regime with a visit before freedom for cuban people watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.144735: step 9400, loss 0.000224565, acc 1
#
#
# <AT_NAME_437/> chose his own personal gains over protecting an elderly widow’s home watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.149695: step 9400, loss 2.13382e-05, acc 1
#
#
# obamas incremental and naïve foreign policy is not rooted in reality i will restore us leadership <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.153672: step 9400, loss 0.000468979, acc 1
#
#
# big defeat last night in nevada for ted cruz and marco rubio <AT_NAME_919/> on <AT_NAME_920/> is working hard to belittle my victory rove is sick <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.158637: step 9400, loss 5.32851e-05, acc 1
#
#
# lying cruz put out a statement “trump rubio are w/obama on gay marriage cruz is the worst liar crazy or very dishonest perhaps all 3 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.163935: step 9400, loss 1.44242e-05, acc 1
#
#
# donald trump can’t prosecute the case against hillary — he’s donated $100000 to her foundation we can’t lose to her in november #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.169183: step 9400, loss 0.000356134, acc 1
#
#
# <AT_NAME_613/> is no ronald reagan  not even close #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.174378: step 9400, loss 0.000286776, acc 1
#
#
# now that bush has wasted $120 million of special interest money on his failed campaign he says he would end super pacs sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.178217: step 9400, loss 4.57753e-05, acc 1
#
#
# this shows what a complete total liar ted cruz is he said he wouldnt have nominated john roberts really <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.181943: step 9400, loss 6.6757e-06, acc 1
#
#
# <AT_NAME_234/> is not a serious candidate we’re living in serious times need a real commanderinchief <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.185696: step 9400, loss 0.000139942, acc 1
#
#
# the statement put out yesterday by <AT_NAME_20/> was a disgrace to good broadcasting and journalism who would ever say something so nasty dumb <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.189399: step 9400, loss 6.90198e-05, acc 1
#
#
# abc news’ <AT_NAME_395/>  “i have never seen christie tougher in this race i have never seen marco rubio more rattled” <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.193044: step 9400, loss 1.41858e-05, acc 1
#
#
# <AT_NAME_53/> <AT_NAME_54/> <AT_NAME_55/> <AT_NAME_56/> and this is the bimbo thats asking presidential questions <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.196978: step 9400, loss 0.00105635, acc 1
#
#
# <AT_NAME_210/> is the only network that does not even mention my very successful event last night $6000000 raised in one hour for our vets <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.200538: step 9400, loss 0.000216103, acc 1
#
#
# <AT_NAME_725/> is so biased it is disgusting they do not want trump to win all negative <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.204105: step 9400, loss 0.00047577, acc 1
#
#
# <AT_NAME_369/> americastop being dupedwake up cruz rubio establishment phonies donaldtrump only truthful not owned candidate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.208201: step 9400, loss 0.000105971, acc 1
#
#
# <AT_NAME_621/> <AT_NAME_622/> <AT_NAME_623/> jeb is incompetent and will lose dont waste your energy on that cry baby <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.212052: step 9400, loss 0.000230643, acc 1
#
#
# <AT_NAME_85/> <AT_NAME_86/> mr trump why does cruz hate canada so much he should embrace his roots its a great country so true <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.216952: step 9400, loss 1.22785e-05, acc 1
#
#
# jeb bush and ted cruz are not electable presidential candidates hillary would destroy them ted may not be eligible to run  born in canada <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.220700: step 9400, loss 2.77754e-05, acc 1
#
#
# vladimir putin is an opportunist hes a bully and we have to face him head on #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.224854: step 9400, loss 0.000354346, acc 1
#
#
# lying ted cruz and lightweight choker marco rubio teamed up last night in a last ditch effort to stop our great movement they failed <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.228544: step 9400, loss 3.81462e-05, acc 1
#
#
# <AT_NAME_128/> <AT_NAME_129/> talk tough now but where were they when they had the chance to act on syria #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.232225: step 9400, loss 0.000178083, acc 1
#
#
# the great state of nebraska can do much better than <AT_NAME_205/> as your senator saw him on <AT_NAME_206/>  totally ineffective wants paid for pols <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.237076: step 9400, loss 0.00010323, acc 1
#
#
# senator <AT_NAME_396/> acted like he was disembodied from the bill it was his bill #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.241518: step 9400, loss 0.000100608, acc 1
#
#
# all you do is win <AT_NAME_612/> really <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.246840: step 9400, loss 0.00283364, acc 1
#
#
# mitt romneywho totally blew an election that should have been won and whose tax returns made him look like a fool is now playing tough guy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.251067: step 9400, loss 7.55758e-05, acc 1
#
#
# millions of $s of false ads paid for by lobbyistsspecial interests of cheater <AT_NAME_547/> and sleepy <AT_NAME_548/> are now running in sc <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.254456: step 9400, loss 0.000120513, acc 1
#
#
# <AT_NAME_968/> <AT_NAME_969/> <AT_NAME_970/> <AT_NAME_971/> hates to see trumps success when he was so pathetic <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.257835: step 9400, loss 5.6146e-05, acc 1
#
#
# failed presidential candidate <AT_NAME_997/> was made to look like a fool by senator harry reid didnt release his tax returns until 9/21/12 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.261274: step 9400, loss 2.53913e-05, acc 1
#
#
# <AT_NAME_816/> why does ted cruz lie so much lets face it ted never created even 1 job his entire life #watch <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.264824: step 9400, loss 1.12056e-05, acc 1
#
#
# ted cruz has now apologized to marco rubio and ben carson for fraud and dirty tricks no wonder he has lost evangelical support <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.269671: step 9400, loss 9.17869e-05, acc 1
#
#
# it is appalling that <AT_NAME_518/> insisted that minors be shipped back to their country of origin like a package marked return to sender <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.272927: step 9400, loss 5.32851e-05, acc 1
#
#
# lightweight choker marco rubio looks like a little boy on stage not presidential material <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.276909: step 9400, loss 2.62257e-05, acc 1
#
#
# the president is obsessed with taxes his latest scheme would hit consumers to pay for even more govt spending <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.280422: step 9400, loss 2.93251e-05, acc 1
#
#
# <AT_NAME_542/> <AT_NAME_543/> good i want to see the court decide what i was always told natural born means  born on american soil <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.284758: step 9400, loss 0.000629346, acc 1
#
#
# nyt agrees <AT_NAME_985/> should release her wall street transcripts day 20 since she said i will look into it <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.290496: step 9400, loss 2.14574e-05, acc 1
#
#
# for your afternoon playlist we have a couple of <AT_NAME_318/> classics from the album scripted <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.294753: step 9400, loss 0.000726198, acc 1
#
#
# amazing that ted cruz cant even get a senator like <AT_NAME_209/> who is easy to endorse him not one senator is endorsing canada ted <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.302933: step 9400, loss 7.11654e-05, acc 1
#
#
# <AT_NAME_751/> is changing their theme from fair and balanced to unfair and unbalanced but dying <AT_NAME_752/> is worsetheir phony poll is a joke <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.308793: step 9400, loss 9.89432e-06, acc 1
#
#
# i will certainly look into it  <AT_NAME_897/> voters deserve to know what she told wall street and big pharma behind closed doors <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.312734: step 9400, loss 0.000308585, acc 1
#
#
# the sheer incompetence at the va is outrageous <AT_NAME_378/> ignores it ill fix it #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.316737: step 9400, loss 0.000263179, acc 1
#
#
# donald trump isnt on stage at the #gopdebate—but you can bet the same backwards ideas and outoftouch rhetoric will be out in force <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.323149: step 9400, loss 5.82916e-05, acc 1
#
#
# i refuse to call megyn kelly a bimbo because that would not be politically correct instead i will only call her a lightweight reporter <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.326761: step 9400, loss 0.000177964, acc 1
#
#
# state department confirms <AT_NAME_198/> looked us in the eye and lied <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.330920: step 9400, loss 0.00055834, acc 1
#
#
# anybody who watched all of ted cruzs far too long rambling overly flamboyant speech last nite would say that was his howard dean moment <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.334744: step 9400, loss 4.78018e-05, acc 1
#
#
# ted cruz said on <AT_NAME_882/> that illegals sent out of country by my administration would come right back as citizens another liecrazy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.339125: step 9400, loss 6.58014e-05, acc 1
#
#
# funny that jeb() didnt want help from his family in his failed campaign and didnt even want to use his last namethen mommy now brother <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.343774: step 9400, loss 3.38549e-05, acc 1
#
#
# if you can’t list one accomplishment by <AT_NAME_354/> how do you know he has the leadership skills to be president <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.348503: step 9400, loss 0.000537489, acc 1
#
#
# icymi i’m the only one who took on <AT_NAME_639/> exposed the flaws in his candidacy he is not a conservative <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.352555: step 9400, loss 0.000231954, acc 1
#
#
# you know before it was called obamacare it was called hillarycare #demdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.356330: step 9400, loss 0.000824707, acc 1
#
#
# greed fraud dishonesty arrogance these are just some of the adjectives we use to describe wall street <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.360609: step 9400, loss 0.00046028, acc 1
#
#
# if donald trump builds his wall the way he built trump tower he’ll be using illegal immigrant labor to do it #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.364867: step 9400, loss 4.44641e-05, acc 1
#
#
# if <AT_NAME_531/> doesn’t clean up his act stop cheating doing negative ads i have standing to sue him for not being a natural born citizen <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.369128: step 9400, loss 9.54821e-05, acc 1
#
#
# just saw the phony ad by cruz  totally false more dirty tricks he got caught in so many lies  is this man crazy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.374790: step 9400, loss 0.000159728, acc 1
#
#
# <AT_NAME_952/> <AT_NAME_953/> mr tough guy romney should be backing trump like trump backed him last time #noloyalty <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.378928: step 9400, loss 1.58547e-05, acc 1
#
#
# jeb used eminent domain took advantage of a disabled vet in the process (2/2) <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.389959: step 9400, loss 0.000270211, acc 1
#
#
# cruz caught cold in lie after denial of push polls like lies w/ <AT_NAME_516/> how can he preach christian values <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.396812: step 9400, loss 5.6742e-05, acc 1
#
#
# jeb failed as jeb he gave up and enlisted mommy and his brother (who got us into the quicksand of iraq) spent $120 millionweakno chance <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.402239: step 9400, loss 0.000196318, acc 1
#
#
# ted cruz should be disqualified from his fraudulent win in iowa weak rnc and republican leadership probably wont let this happen sad <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.407569: step 9400, loss 0.000121705, acc 1
#
#
# trump’s “record or lack thereof proves he is more of a proclinton democrat than a reagan republican <AT_NAME_173/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.414487: step 9400, loss 7.1523e-05, acc 1
#
#
# <AT_NAME_938/> oh great <AT_NAME_939/> is doing a <AT_NAME_940/> on <AT_NAME_941/> like losing the presidency wasnt enough #trump2016 hes a fool <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.422442: step 9400, loss 3.06363e-05, acc 1
#
#
# <AT_NAME_18/> trembling at being questioned by <AT_NAME_19/> channels monty python <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.429111: step 9400, loss 0.000100369, acc 1
#
#
# <AT_NAME_218/> <AT_NAME_219/> <AT_NAME_220/> damn fox is really acting like a baby today i guess trump got under their skin  pretty biased <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.432802: step 9400, loss 2.02654e-05, acc 1
#
#
# asked about his record <AT_NAME_387/> only gives general answers on how proud he was of his time as a public servant <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.436321: step 9400, loss 4.01727e-05, acc 1
#
#
# thanks <AT_NAME_179/> helps when you know what you stand for cc <AT_NAME_180/> <AT_NAME_181/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.440249: step 9400, loss 0.00166409, acc 1
#
#
# radical islamic jihadists want to impose their faith upon each and every one of us #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.444084: step 9400, loss 0.000119798, acc 1
#
#
# <AT_NAME_913/> believes republicans should set the standard for disclosure of her wall street speeches aren’t we better than that <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# example
# 2016-03-05T03:12:36.447842: step 9400, loss 0.00012552, acc 1
#
#
# ...
#
#
# under the #carsonflattax each citizen pays the same % and there is no danger of the government favoring anyone <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.421078: step 9400, loss 6.55649e-06, acc 1
#
#
# these are the top national security priorities marco would address as president #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.427962: step 9400, loss 0.000124208, acc 1
#
#
# glad to join <AT_NAME_240/> and <AT_NAME_241/> this morning to speak about tonights #iacaucus <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.434189: step 9400, loss 2.38419e-07, acc 1
#
#
# we cannot mix radical muslim jihadists with every day muslims #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.442219: step 9400, loss 3.52853e-05, acc 1
#
#
# the lines are clear <AT_NAME_604/> right now supports citizenship for 11 million people here illegally i oppose it #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.448549: step 9400, loss 5.48361e-06, acc 1
#
#
# watch the #gopdebate on 📺 <AT_NAME_126/> follow along online with us here 💻 <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.454849: step 9400, loss 0, acc 1
#
#
# we can reignite the promise of america and with your help we will join the #cruzcrew <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.460505: step 9400, loss 0, acc 1
#
#
# today im proud to release my plan on how we can destroy #isis read more <URL/> #carsonpolicy <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.466066: step 9400, loss 7.15256e-07, acc 1
#
#
# just as the united states opposed the spread of communism it must now oppose the spread of terrorism in all corners of the world <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.470141: step 9400, loss 1.19209e-07, acc 1
#
#
# the red hot <AT_NAME_741/> have a message for you <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.473757: step 9400, loss 2.31263e-05, acc 1
#
#
# we cant let republicans rip away <AT_NAME_994/> progress text imwithher to 47246 if you agree <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.477233: step 9400, loss 4.41073e-06, acc 1
#
#
# its outrageous that republicanshave already pledged to block any [supreme court] replacement that president obama nominates —hillary <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.480968: step 9400, loss 1.07288e-05, acc 1
#
#
# on the questions of life and marriage a record matters #goptownhall <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.484704: step 9400, loss 7.8079e-05, acc 1
#
#
# racism sexism and bigotry is not what this country is supposed to be about #bernieinsc <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.488013: step 9400, loss 2.45568e-05, acc 1
#
#
# black families are denied mortgages nearly 3x as often as white families we need to tear down barriers of systemic racism that still exist <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.492721: step 9400, loss 3.33785e-06, acc 1
#
#
# ✔️ wall street ✔️ pricegouging pharmaceutical companies ✔️ the gun lobby we will go after industries when they hurt families #demdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.496344: step 9400, loss 2.38419e-07, acc 1
#
#
# will be at fort worth (texas) convention center at 1130 am big crowd  get there early big announcement to be made <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.500158: step 9400, loss 1.66893e-06, acc 1
#
#
# america’s most urgent foreign policy priority should be to defeat and destroy radical islamic terrorism <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.506815: step 9400, loss 1.01327e-05, acc 1
#
#
# if i am elected president we will not be drafting our daughters into combat #goptownhall <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.511384: step 9400, loss 0, acc 1
#
#
# thank you baton rouge louisiana we will #makeamericagreatagain #trump2016 <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.517191: step 9400, loss 0, acc 1
#
#
# i am not a singleissue candidate and i do not believe we live in a singleissue country #demdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.522875: step 9400, loss 0, acc 1
#
#
# #cruzcrew tune in to tonights #gopdebate on fox news​ at 9 pm et <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.528236: step 9400, loss 1.22785e-05, acc 1
#
#
# salem nh bring your friends family and neighbors to #choosecruz on 2/9 <URL/> #fitn #nhpolitics <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.539669: step 9400, loss 0, acc 1
#
#
# during this #gopdebate commercial break just a reminder to follow along with us on our live blog <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.547065: step 9400, loss 0, acc 1
#
#
# new fox news debate video i will unify the republican party defeat hillary clinton <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.551854: step 9400, loss 2.50339e-06, acc 1
#
#
# this is it—the #iowacaucus is today if you’re standing with hillary rt to say #imwithher <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.556168: step 9400, loss 3.57628e-07, acc 1
#
#
# need to look up your polling location <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.559600: step 9400, loss 3.9339e-06, acc 1
#
#
# hillary on the flint water crisis would it have happened if they were rich and white instead of poor and black #nhdems2016 <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.563006: step 9400, loss 1.43051e-06, acc 1
#
#
# <AT_NAME_839/> this is the best reaction shot ive ever seen lol #trump2016 <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.567002: step 9400, loss 6.07966e-06, acc 1
#
#
# last night we served notice to the political and economic establishment of this country the people want real change <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.571554: step 9400, loss 0, acc 1
#
#
# nevada if youre in line stay there—and talk to your neighbors about hillary <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.575700: step 9400, loss 2.14576e-06, acc 1
#
#
# team jeb taking over follow along with us during the #gopdebate here → <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.579955: step 9400, loss 4.76837e-07, acc 1
#
#
# we must stop making our political process about spectacle and must instead make it about the future of our nation <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.584059: step 9400, loss 0, acc 1
#
#
# americans dont care about who is establishment or who is grassroots #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.587728: step 9400, loss 4.06495e-05, acc 1
#
#
# <AT_NAME_800/> like #jimmycarter says im more dangerous to leftists bc i actually believe in the constitution true <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.591451: step 9400, loss 1.43051e-06, acc 1
#
#
# in 93 hours it’ll be time for iowans to decide i’d be honored if you would caucus for me on monday night #gopdebate <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.597945: step 9400, loss 1.19209e-06, acc 1
#
#
# millions of families like karla’s live in fear of deportation we need a president who will fight to protect them <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.604241: step 9400, loss 1.19209e-07, acc 1
#
#
# no one can get this done alone—not even the president of the united states it’s got to be the mission of our entire nation <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.610627: step 9400, loss 7.15256e-07, acc 1
#
#
# more proof that women need a president who will stop attacks on womens health in their tracks <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.615256: step 9400, loss 1.19209e-06, acc 1
#
#
# thank you plymouth new hampshire #fitn #nhprimary <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.620139: step 9400, loss 0, acc 1
#
#
# join me tomorrow in plymouth new hampshire #fitn #nhprimary <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.625057: step 9400, loss 0, acc 1
#
#
# a consistent conservative record of accomplishments vs …nothing <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.631573: step 9400, loss 7.15256e-07, acc 1
#
#
# heres an easy way to help hillary win in new hampshire—it only takes 5 minutes <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.637089: step 9400, loss 5.3644e-06, acc 1
#
#
# thank you nevada we will make america safe great again <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.641156: step 9400, loss 0, acc 1
#
#
# our newest tv ad highlights the most important part of my life my family <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.644919: step 9400, loss 2.38419e-07, acc 1
#
#
# ben carson picks up endorsement reveals plan to care for veterans  breitbart <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.649726: step 9400, loss 1.19209e-07, acc 1
#
#
# in 2015 <AT_NAME_842/> leapt into record books as the worlds most decorated woman gymnast <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.653305: step 9400, loss 7.15256e-07, acc 1
#
#
# totally unauthorized do not pay i am self funding my campaign notice has just been withdrawn #trump2016 #makeamericagreatagain <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.657116: step 9400, loss 2.74181e-06, acc 1
#
#
# show marco youre on the team chip in $5 right now right from twitter <URL/> #gopdebate <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.660772: step 9400, loss 1.19209e-07, acc 1
#
#
# we had awesome crowds at our two town halls in spartanburg and columbia today <URL/> #scformarco <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.664064: step 9400, loss 0, acc 1
#
#
# <AT_NAME_923/> glad to have you on our team thanks for the support <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.667512: step 9400, loss 0, acc 1
#
#
# 29 million americans don’t have health insurance 31 million are underinsured that’s rationing those are wait times #demtownhall <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.670942: step 9400, loss 1.66893e-06, acc 1
#
#
# standing room only in mount pleasant thank you all <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.674433: step 9400, loss 1.78814e-06, acc 1
#
#
# couldnt agree more <AT_NAME_658/> its time to act on gun violence thank you for telling these stories today <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.679019: step 9400, loss 4.76837e-07, acc 1
#
#
# the puerto rican senate just confirmed maite oronoz rodríguez making her the first lgbt chief justice in the us <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.683809: step 9400, loss 7.15256e-07, acc 1
#
#
# listen to why charlie is supporting our campaign #fits #choosecruz join him <URL/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.688290: step 9400, loss 3.57628e-07, acc 1
#
#
# i will be interviewed from charleston south carolina by <AT_NAME_734/> and <AT_NAME_735/> at 8pm tonight for one hour on <AT_NAME_736/> enjoy <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.691877: step 9400, loss 9.53674e-07, acc 1
#
#
# sorry to miss you but glad you got to meet <AT_NAME_488/> <URL/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/> <PAD/>
# nonexample
# 2016-03-05T03:12:37.697178: step 9400, loss 2.38419e-07, acc 1
